# %% [markdown]
# # CytoTable object graph analysis
#
# This notebook explores how CytoTable objects operate. The work is related to [CytoTable#75](https://github.com/cytomining/CytoTable/issues/75).

# %%
import gc
import sys

import cytotable
import pandas as pd

gc.set_debug(gc.DEBUG_LEAK)

cytotable.convert(
    source_path="./examples/data/all_cellprofiler.sqlite",
    dest_path="./examples/data/test-result.parquet",
    dest_datatype="parquet",
    preset="cellprofiler_sqlite_pycytominer",
)

collected = gc.collect()
if gc.garbage:
    print(f"Memory leak detected: {len(gc.garbage)} objects")
    df = pd.DataFrame(
        [
            {
                "id": id(obj),
                "type": type(obj),
                "refcount": sys.getrefcount(obj),
                "repr": repr(obj),
                "size": sys.getsizeof(obj),
            }
            for obj in gc.garbage
        ]
    )

df.head()
# Out:
# Memory leak detected: 1119 objects
# gc: collectable <list 0x13a681300>
# gc: collectable <list 0x13c003580>
# gc: collectable <dict 0x13beea980>
# gc: collectable <AppFuture 0x124f01d00>
# gc: collectable <Condition 0x124f01040>
# gc: collectable <builtin_function_or_method 0x13c12e1d0>
# gc: collectable <dict 0x13bf21500>
# gc: collectable <builtin_function_or_method 0x13c12e220>
# gc: collectable <builtin_function_or_method 0x13c12e270>
# gc: collectable <builtin_function_or_method 0x13c12e2c0>
# gc: collectable <builtin_function_or_method 0x13c12e310>
# gc: collectable <collections.deque 0x11a1397c0>
# gc: collectable <dict 0x13c003c80>
# gc: collectable <list 0x13c003040>
# gc: collectable <list 0x13bf21800>
# gc: collectable <list 0x13bf21740>
# gc: collectable <list 0x118916880>
# gc: collectable <method 0x13c123680>
# gc: collectable <functools.partial 0x13c12e3b0>
# gc: collectable <tuple 0x1104014c0>
# gc: collectable <list 0x13c039f40>
# gc: collectable <Future 0x13bebcf70>
# gc: collectable <Condition 0x13bebcf40>
# gc: collectable <builtin_function_or_method 0x13c12e4a0>
# gc: collectable <dict 0x13bec7ec0>
# gc: collectable <builtin_function_or_method 0x13c12e590>
# gc: collectable <builtin_function_or_method 0x13c12e5e0>
# gc: collectable <builtin_function_or_method 0x13c12e630>
# gc: collectable <builtin_function_or_method 0x13c12e680>
# gc: collectable <collections.deque 0x13b7cee80>
# gc: collectable <dict 0x13bec7cc0>
# gc: collectable <list 0x13c039f00>
# gc: collectable <list 0x13c039e40>
# gc: collectable <method 0x13c123700>
# gc: collectable <functools.partial 0x13c12e450>
# gc: collectable <tuple 0x119d9d5b0>
# gc: collectable <list 0x13c039880>
# gc: collectable <dict 0x119d7d480>
# gc: collectable <list 0x13c123cc0>
# gc: collectable <list 0x13c0397c0>
# gc: collectable <dict 0x13c131400>
# gc: collectable <AppFuture 0x13bebc8e0>
# gc: collectable <Condition 0x13bebcfd0>
# gc: collectable <builtin_function_or_method 0x119d9b540>
# gc: collectable <dict 0x13c123940>
# gc: collectable <builtin_function_or_method 0x13c12e9a0>
# gc: collectable <builtin_function_or_method 0x13c12e950>
# gc: collectable <builtin_function_or_method 0x13c12ec70>
# gc: collectable <builtin_function_or_method 0x13c12ecc0>
# gc: collectable <collections.deque 0x13bf9e580>
# gc: collectable <dict 0x13c003ec0>
# gc: collectable <list 0x13c039740>
# gc: collectable <list 0x13c0396c0>
# gc: collectable <list 0x13c039540>
# gc: collectable <list 0x13c131900>
# gc: collectable <method 0x13c1317c0>
# gc: collectable <functools.partial 0x13c12ed60>
# gc: collectable <tuple 0x13abc9490>
# gc: collectable <list 0x13b76ba80>
# gc: collectable <Future 0x13beeb0a0>
# gc: collectable <Condition 0x13beeb0d0>
# gc: collectable <builtin_function_or_method 0x13c12edb0>
# gc: collectable <dict 0x13c1318c0>
# gc: collectable <builtin_function_or_method 0x13c12ef40>
# gc: collectable <builtin_function_or_method 0x13c12ef90>
# gc: collectable <builtin_function_or_method 0x13c135040>
# gc: collectable <builtin_function_or_method 0x13c135090>
# gc: collectable <collections.deque 0x13bf91dc0>
# gc: collectable <dict 0x13c1319c0>
# gc: collectable <list 0x13b776f40>
# gc: collectable <list 0x13b776e80>
# gc: collectable <list 0x13b6b4d80>
# gc: collectable <list 0x13b7769c0>
# gc: collectable <dict 0x13c131e80>
# gc: collectable <AppFuture 0x13beeb4f0>
# gc: collectable <Condition 0x13beeb400>
# gc: collectable <builtin_function_or_method 0x13c12eea0>
# gc: collectable <dict 0x13c131f00>
# gc: collectable <builtin_function_or_method 0x13c12ee50>
# gc: collectable <builtin_function_or_method 0x13c12eef0>
# gc: collectable <builtin_function_or_method 0x13c1352c0>
# gc: collectable <builtin_function_or_method 0x13c1353b0>
# gc: collectable <collections.deque 0x13bf83a00>
# gc: collectable <dict 0x13c131880>
# gc: collectable <list 0x13bed6a40>
# gc: collectable <list 0x13bed6440>
# gc: collectable <method 0x13c131800>
# gc: collectable <functools.partial 0x13c12ee00>
# gc: collectable <tuple 0x119992f40>
# gc: collectable <list 0x13c039600>
# gc: collectable <list 0x13c123d00>
# gc: collectable <method 0x13c131780>
# gc: collectable <functools.partial 0x13c1354a0>
# gc: collectable <tuple 0x13b6d1a30>
# gc: collectable <list 0x13c131f40>
# gc: collectable <Future 0x13beeb580>
# gc: collectable <Condition 0x13beeb5b0>
# gc: collectable <builtin_function_or_method 0x13c135450>
# gc: collectable <dict 0x13c1315c0>
# gc: collectable <builtin_function_or_method 0x13c135630>
# gc: collectable <builtin_function_or_method 0x13c135680>
# gc: collectable <builtin_function_or_method 0x13c1356d0>
# gc: collectable <builtin_function_or_method 0x13c135720>
# gc: collectable <collections.deque 0x13bf83a60>
# gc: collectable <dict 0x13c131ec0>
# gc: collectable <list 0x13c131e40>
# gc: collectable <list 0x13c138180>
# gc: collectable <cell 0x13beeb880>
# gc: collectable <cell 0x13beeb8b0>
# gc: collectable <cell 0x13beeb8e0>
# gc: collectable <cell 0x13beeb910>
# gc: collectable <cell 0x13beeb940>
# gc: collectable <tuple 0x13bf11680>
# gc: collectable <function 0x13c1308b0>
# gc: collectable <method 0x13c131bc0>
# gc: collectable <functools.partial 0x13c1354f0>
# gc: collectable <tuple 0x13b6d1ac0>
# gc: collectable <dict 0x13c123c80>
# gc: collectable <cell 0x13beeb490>
# gc: collectable <cell 0x13beeb460>
# gc: collectable <list 0x13b6b4d40>
# gc: collectable <list 0x13c138380>
# gc: collectable <dict 0x13c138100>
# gc: collectable <AppFuture 0x13beeb970>
# gc: collectable <Condition 0x13beeb9d0>
# gc: collectable <builtin_function_or_method 0x13c1355e0>
# gc: collectable <dict 0x13c138600>
# gc: collectable <builtin_function_or_method 0x13c135540>
# gc: collectable <builtin_function_or_method 0x13c135a40>
# gc: collectable <builtin_function_or_method 0x13c135a90>
# gc: collectable <builtin_function_or_method 0x13c135ae0>
# gc: collectable <collections.deque 0x13bfc32e0>
# gc: collectable <dict 0x13c138480>
# gc: collectable <list 0x13c1386c0>
# gc: collectable <list 0x13c138740>
# gc: collectable <list 0x13c138340>
# gc: collectable <list 0x13c1385c0>
# gc: collectable <method 0x13c138940>
# gc: collectable <functools.partial 0x13c135c20>
# gc: collectable <tuple 0x13b6d1be0>
# gc: collectable <tuple 0x119d72480>
# gc: collectable <function 0x13c130a60>
# gc: collectable <dict 0x13c138880>
# gc: collectable <cell 0x13beeba90>
# gc: collectable <cell 0x13beebac0>
# gc: collectable <list 0x13c131f80>
# gc: collectable <list 0x13c138640>
# gc: collectable <dict 0x13c138980>
# gc: collectable <AppFuture 0x13beebb20>
# gc: collectable <Condition 0x13beebb50>
# gc: collectable <builtin_function_or_method 0x13c135bd0>
# gc: collectable <dict 0x13c138a40>
# gc: collectable <builtin_function_or_method 0x13c135c70>
# gc: collectable <builtin_function_or_method 0x13c135cc0>
# gc: collectable <builtin_function_or_method 0x13c135b80>
# gc: collectable <builtin_function_or_method 0x13c135d10>
# gc: collectable <collections.deque 0x13bfd94c0>
# gc: collectable <dict 0x13c1388c0>
# gc: collectable <list 0x13c1389c0>
# gc: collectable <list 0x13c138a00>
# gc: collectable <list 0x13c138ac0>
# gc: collectable <list 0x13c138b00>
# gc: collectable <method 0x13c138cc0>
# gc: collectable <functools.partial 0x13c135e50>
# gc: collectable <tuple 0x13b6726a0>
# gc: collectable <tuple 0x1144ebd80>
# gc: collectable <function 0x13c130af0>
# gc: collectable <dict 0x13c138c00>
# gc: collectable <cell 0x13beebc10>
# gc: collectable <cell 0x13beebfd0>
# gc: collectable <list 0x13c138040>
# gc: collectable <list 0x13c138a80>
# gc: collectable <dict 0x13c138d80>
# gc: collectable <AppFuture 0x13beebf40>
# gc: collectable <Condition 0x13beebf10>
# gc: collectable <builtin_function_or_method 0x13c135e00>
# gc: collectable <dict 0x13c138dc0>
# gc: collectable <builtin_function_or_method 0x13c135ea0>
# gc: collectable <builtin_function_or_method 0x13c135ef0>
# gc: collectable <builtin_function_or_method 0x13c135db0>
# gc: collectable <builtin_function_or_method 0x13c135f40>
# gc: collectable <collections.deque 0x13bfd9ac0>
# gc: collectable <dict 0x13c138c40>
# gc: collectable <list 0x13c138d00>
# gc: collectable <list 0x13c138d40>
# gc: collectable <PosixPath 0x13bfc3400>
# gc: collectable <list 0x13c131dc0>
# gc: collectable <list 0x13c138e80>
# gc: collectable <list 0x13c138700>
# gc: collectable <list 0x13c138e40>
# gc: collectable <method 0x13c13c040>
# gc: collectable <functools.partial 0x13c13b540>
# gc: collectable <tuple 0x13b673730>
# gc: collectable <Future 0x13bf3a610>
# gc: collectable <Condition 0x13bf3a670>
# gc: collectable <builtin_function_or_method 0x13c13b4a0>
# gc: collectable <dict 0x13c13c1c0>
# gc: collectable <builtin_function_or_method 0x13c13b630>
# gc: collectable <builtin_function_or_method 0x13c13b680>
# gc: collectable <builtin_function_or_method 0x13c13b6d0>
# gc: collectable <builtin_function_or_method 0x13c13b720>
# gc: collectable <collections.deque 0x13bfc3340>
# gc: collectable <dict 0x13c13c200>
# gc: collectable <list 0x1199b4580>
# gc: collectable <list 0x13c13c240>
# gc: collectable <tuple 0x13c131540>
# gc: collectable <function 0x13c130940>
# gc: collectable <tuple 0x119eabf00>
# gc: collectable <function 0x13c130d30>
# gc: collectable <method 0x13c131d80>
# gc: collectable <functools.partial 0x13c13b090>
# gc: collectable <tuple 0x124e50a60>
# gc: collectable <method 0x1256ba800>
# gc: collectable <functools.partial 0x13c13b450>
# gc: collectable <tuple 0x13b68dc40>
# gc: collectable <list 0x13c13c840>
# gc: collectable <list 0x13c138800>
# gc: collectable <PosixPath 0x13bfd9b20>
# gc: collectable <dict 0x13c123d40>
# gc: collectable <dict 0x13c131c00>
# gc: collectable <list 0x13c138e00>
# gc: collectable <list 0x13c13c4c0>
# gc: collectable <PosixPath 0x13c1209a0>
# gc: collectable <dict 0x13c131c40>
# gc: collectable <list 0x13c13c800>
# gc: collectable <list 0x13c13ccc0>
# gc: collectable <PosixPath 0x13c120ac0>
# gc: collectable <dict 0x13c131c80>
# gc: collectable <list 0x13c13ca00>
# gc: collectable <list 0x13c13cac0>
# gc: collectable <PosixPath 0x13c1293a0>
# gc: collectable <dict 0x13c131cc0>
# gc: collectable <list 0x13c13c8c0>
# gc: collectable <Future 0x13bf3adf0>
# gc: collectable <Condition 0x13bf3ae20>
# gc: collectable <builtin_function_or_method 0x13c13ba90>
# gc: collectable <dict 0x13c1380c0>
# gc: collectable <builtin_function_or_method 0x13c13bdb0>
# gc: collectable <builtin_function_or_method 0x13c13be00>
# gc: collectable <builtin_function_or_method 0x13c13be50>
# gc: collectable <builtin_function_or_method 0x13c13bea0>
# gc: collectable <collections.deque 0x13bfe91c0>
# gc: collectable <dict 0x13c1383c0>
# gc: collectable <list 0x13c13cbc0>
# gc: collectable <list 0x13c13cc00>
# gc: collectable <list 0x13c13cc40>
# gc: collectable <Future 0x13bf3ad00>
# gc: collectable <Condition 0x13bf3ad60>
# gc: collectable <builtin_function_or_method 0x13c13bd60>
# gc: collectable <dict 0x13c13c540>
# gc: collectable <builtin_function_or_method 0x13c13f090>
# gc: collectable <builtin_function_or_method 0x13c13f0e0>
# gc: collectable <builtin_function_or_method 0x13c13f130>
# gc: collectable <builtin_function_or_method 0x13c13f180>
# gc: collectable <collections.deque 0x13bfeaee0>
# gc: collectable <dict 0x13c131d00>
# gc: collectable <list 0x13c13cc80>
# gc: collectable <list 0x13c13c080>
# gc: collectable <list 0x13c13ca40>
# gc: collectable <method 0x13c138f00>
# gc: collectable <functools.partial 0x13c13bd10>
# gc: collectable <tuple 0x13a30f730>
# gc: collectable <dict 0x124e3eb80>
# gc: collectable <list 0x13c138b80>
# gc: collectable <list 0x13c13c780>
# gc: collectable <list 0x13c13cd40>
# gc: collectable <cell 0x13beeb5e0>
# gc: collectable <cell 0x13bebc850>
# gc: collectable <cell 0x13bf3acd0>
# gc: collectable <cell 0x13bf3ad90>
# gc: collectable <cell 0x13bf3a9d0>
# gc: collectable <tuple 0x13b7c94a0>
# gc: collectable <function 0x13c130c10>
# gc: collectable <dict 0x13c138440>
# gc: collectable <list 0x13c13ca80>
# gc: collectable <list 0x13c13cb40>
# gc: collectable <dict 0x13c131980>
# gc: collectable <AppFuture 0x13bf3ac10>
# gc: collectable <Condition 0x13bf3abe0>
# gc: collectable <builtin_function_or_method 0x13c13bf90>
# gc: collectable <dict 0x13c13c580>
# gc: collectable <builtin_function_or_method 0x13c13b5e0>
# gc: collectable <builtin_function_or_method 0x13c13f040>
# gc: collectable <builtin_function_or_method 0x13c13f220>
# gc: collectable <builtin_function_or_method 0x13c13f270>
# gc: collectable <collections.deque 0x13c0fa2e0>
# gc: collectable <dict 0x13c13c740>
# gc: collectable <list 0x13c13cb80>
# gc: collectable <list 0x13c13ce00>
# gc: collectable <list 0x13c13ce40>
# gc: collectable <list 0x13c13ce80>
# gc: collectable <method 0x13c13cec0>
# gc: collectable <functools.partial 0x13c13f310>
# gc: collectable <tuple 0x13a6fe2e0>
# gc: collectable <list 0x13c13cfc0>
# gc: collectable <Future 0x13bf3a940>
# gc: collectable <Condition 0x13bf3a910>
# gc: collectable <builtin_function_or_method 0x13c13f360>
# gc: collectable <dict 0x13c142140>
# gc: collectable <builtin_function_or_method 0x13c13f4f0>
# gc: collectable <builtin_function_or_method 0x13c13f540>
# gc: collectable <builtin_function_or_method 0x13c13f590>
# gc: collectable <builtin_function_or_method 0x13c13f5e0>
# gc: collectable <collections.deque 0x13bfeaf40>
# gc: collectable <dict 0x13c142180>
# gc: collectable <list 0x13c142100>
# gc: collectable <list 0x13c1421c0>
# gc: collectable <method 0x13c1420c0>
# gc: collectable <functools.partial 0x13c13bb30>
# gc: collectable <tuple 0x1256f7250>
# gc: collectable <list 0x13c131940>
# gc: collectable <dict 0x13c142240>
# gc: collectable <dict 0x13c13cf80>
# gc: collectable <list 0x13c13cd80>
# gc: collectable <list 0x13c13cdc0>
# gc: collectable <dict 0x13c13c280>
# gc: collectable <AppFuture 0x13bf3a3a0>
# gc: collectable <Condition 0x13bf3a820>
# gc: collectable <builtin_function_or_method 0x13c13f3b0>
# gc: collectable <dict 0x13c138fc0>
# gc: collectable <builtin_function_or_method 0x13c13f450>
# gc: collectable <builtin_function_or_method 0x13c13f4a0>
# gc: collectable <builtin_function_or_method 0x13c13f680>
# gc: collectable <builtin_function_or_method 0x13c13f6d0>
# gc: collectable <collections.deque 0x13c129400>
# gc: collectable <dict 0x13c142280>
# gc: collectable <list 0x13c142400>
# gc: collectable <list 0x13c142380>
# gc: collectable <list 0x13c1422c0>
# gc: collectable <list 0x13c142500>
# gc: collectable <method 0x13c142540>
# gc: collectable <functools.partial 0x13c13f770>
# gc: collectable <tuple 0x13bf2b7f0>
# gc: collectable <list 0x13c1425c0>
# gc: collectable <Future 0x13bf3a700>
# gc: collectable <Condition 0x13bf3a6d0>
# gc: collectable <builtin_function_or_method 0x13c13f7c0>
# gc: collectable <dict 0x13c142700>
# gc: collectable <builtin_function_or_method 0x13c13f950>
# gc: collectable <builtin_function_or_method 0x13c13f9a0>
# gc: collectable <builtin_function_or_method 0x13c13f9f0>
# gc: collectable <builtin_function_or_method 0x13c13fa40>
# gc: collectable <collections.deque 0x13c129460>
# gc: collectable <dict 0x13c142740>
# gc: collectable <list 0x13c1426c0>
# gc: collectable <list 0x13c142780>
# gc: collectable <method 0x13c142680>
# gc: collectable <functools.partial 0x13c13bae0>
# gc: collectable <tuple 0x13a1ea7f0>
# gc: collectable <list 0x13c142480>
# gc: collectable <dict 0x13c142800>
# gc: collectable <dict 0x13c142580>
# gc: collectable <list 0x13c138780>
# gc: collectable <list 0x13c1424c0>
# gc: collectable <dict 0x13c142200>
# gc: collectable <AppFuture 0x13bf3aee0>
# gc: collectable <Condition 0x13bf3a4f0>
# gc: collectable <builtin_function_or_method 0x13c13f810>
# gc: collectable <dict 0x13c142040>
# gc: collectable <builtin_function_or_method 0x13c13f8b0>
# gc: collectable <builtin_function_or_method 0x13c13f900>
# gc: collectable <builtin_function_or_method 0x13c13fae0>
# gc: collectable <builtin_function_or_method 0x13c13fb30>
# gc: collectable <collections.deque 0x13c1294c0>
# gc: collectable <dict 0x13c142840>
# gc: collectable <list 0x13c1429c0>
# gc: collectable <list 0x13c142940>
# gc: collectable <list 0x13c142880>
# gc: collectable <list 0x13c142ac0>
# gc: collectable <method 0x13c142b00>
# gc: collectable <functools.partial 0x13c13fbd0>
# gc: collectable <tuple 0x13a1ea5b0>
# gc: collectable <list 0x13c142b80>
# gc: collectable <Future 0x13bf3a2e0>
# gc: collectable <Condition 0x13bf3a2b0>
# gc: collectable <builtin_function_or_method 0x13c13fc20>
# gc: collectable <dict 0x13c142cc0>
# gc: collectable <builtin_function_or_method 0x13c13fdb0>
# gc: collectable <builtin_function_or_method 0x13c13fe00>
# gc: collectable <builtin_function_or_method 0x13c13fe50>
# gc: collectable <builtin_function_or_method 0x13c13fea0>
# gc: collectable <collections.deque 0x13c129520>
# gc: collectable <dict 0x13c142d00>
# gc: collectable <list 0x13c142c80>
# gc: collectable <list 0x13c142d40>
# gc: collectable <method 0x13c142c40>
# gc: collectable <functools.partial 0x13c13fc70>
# gc: collectable <tuple 0x13bf2b6a0>
# gc: collectable <list 0x13c142e40>
# gc: collectable <dict 0x13c142dc0>
# gc: collectable <dict 0x13c142b40>
# gc: collectable <list 0x13c1423c0>
# gc: collectable <list 0x13c142a80>
# gc: collectable <dict 0x13c1427c0>
# gc: collectable <AppFuture 0x13bf3a880>
# gc: collectable <Condition 0x13abb8490>
# gc: collectable <builtin_function_or_method 0x13c13fd10>
# gc: collectable <dict 0x13c142600>
# gc: collectable <builtin_function_or_method 0x13c13f400>
# gc: collectable <builtin_function_or_method 0x13c13fd60>
# gc: collectable <builtin_function_or_method 0x13c13ff40>
# gc: collectable <builtin_function_or_method 0x13c13ff90>
# gc: collectable <collections.deque 0x13c129580>
# gc: collectable <dict 0x13c142e00>
# gc: collectable <list 0x13c142f80>
# gc: collectable <list 0x13c142f00>
# gc: collectable <list 0x13c143040>
# gc: collectable <list 0x13c1430c0>
# gc: collectable <method 0x13c143100>
# gc: collectable <functools.partial 0x13c144090>
# gc: collectable <tuple 0x13beedeb0>
# gc: collectable <list 0x13c143180>
# gc: collectable <Future 0x13abb8610>
# gc: collectable <Condition 0x13abb87c0>
# gc: collectable <builtin_function_or_method 0x13c1440e0>
# gc: collectable <dict 0x13c1432c0>
# gc: collectable <builtin_function_or_method 0x13c144270>
# gc: collectable <builtin_function_or_method 0x13c1442c0>
# gc: collectable <builtin_function_or_method 0x13c144310>
# gc: collectable <builtin_function_or_method 0x13c144360>
# gc: collectable <collections.deque 0x13c1295e0>
# gc: collectable <dict 0x13c143300>
# gc: collectable <list 0x13c143280>
# gc: collectable <list 0x13c143340>
# gc: collectable <method 0x13c143240>
# gc: collectable <functools.partial 0x13c13f860>
# gc: collectable <tuple 0x13b7c6070>
# gc: collectable <list 0x13c142a40>
# gc: collectable <dict 0x13c1433c0>
# gc: collectable <list 0x13c1435c0>
# gc: collectable <list 0x13c142980>
# gc: collectable <dict 0x13c143480>
# gc: collectable <list 0x13c142f40>
# gc: collectable <list 0x13c143580>
# gc: collectable <dict 0x13c143400>
# gc: collectable <AppFuture 0x13abb8190>
# gc: collectable <Condition 0x13abb84f0>
# gc: collectable <builtin_function_or_method 0x13c144130>
# gc: collectable <dict 0x13c142ec0>
# gc: collectable <builtin_function_or_method 0x13c1441d0>
# gc: collectable <builtin_function_or_method 0x13c144220>
# gc: collectable <builtin_function_or_method 0x13c144400>
# gc: collectable <builtin_function_or_method 0x13c144450>
# gc: collectable <collections.deque 0x13c129640>
# gc: collectable <dict 0x13c142bc0>
# gc: collectable <list 0x13c143440>
# gc: collectable <list 0x13c143640>
# gc: collectable <list 0x13c1436c0>
# gc: collectable <list 0x13c143700>
# gc: collectable <method 0x13c143740>
# gc: collectable <functools.partial 0x13c1444f0>
# gc: collectable <tuple 0x13abc3ac0>
# gc: collectable <list 0x13c143800>
# gc: collectable <Future 0x13abb8ee0>
# gc: collectable <Condition 0x13abb8310>
# gc: collectable <builtin_function_or_method 0x13c1445e0>
# gc: collectable <dict 0x13c143980>
# gc: collectable <builtin_function_or_method 0x13c144720>
# gc: collectable <builtin_function_or_method 0x13c144770>
# gc: collectable <builtin_function_or_method 0x13c1447c0>
# gc: collectable <builtin_function_or_method 0x13c144810>
# gc: collectable <collections.deque 0x13c1296a0>
# gc: collectable <dict 0x13c1439c0>
# gc: collectable <list 0x13c143900>
# gc: collectable <list 0x13c143a00>
# gc: collectable <method 0x13c1438c0>
# gc: collectable <functools.partial 0x13c144590>
# gc: collectable <tuple 0x1256f7850>
# gc: collectable <dict 0x13c143780>
# gc: collectable <cell 0x13abb8430>
# gc: collectable <cell 0x13abb83a0>
# gc: collectable <list 0x13c143080>
# gc: collectable <list 0x13c143680>
# gc: collectable <dict 0x13c143e80>
# gc: collectable <AppFuture 0x13abb80a0>
# gc: collectable <Condition 0x13be965e0>
# gc: collectable <builtin_function_or_method 0x13c144630>
# gc: collectable <dict 0x13c143f40>
# gc: collectable <builtin_function_or_method 0x13c1446d0>
# gc: collectable <builtin_function_or_method 0x13c144680>
# gc: collectable <builtin_function_or_method 0x13c1448b0>
# gc: collectable <builtin_function_or_method 0x13c144900>
# gc: collectable <collections.deque 0x13c129700>
# gc: collectable <dict 0x13c143f00>
# gc: collectable <list 0x13c143a80>
# gc: collectable <list 0x13c143f80>
# gc: collectable <list 0x13c146040>
# gc: collectable <list 0x13c146080>
# gc: collectable <method 0x13c146240>
# gc: collectable <functools.partial 0x13c144a90>
# gc: collectable <tuple 0x1256f7430>
# gc: collectable <tuple 0x1151e0a00>
# gc: collectable <function 0x13c130f70>
# gc: collectable <tuple 0x13a7e1280>
# gc: collectable <cython_function_or_method 0x13c173c70>
# gc: collectable <cython_function_or_method 0x13c173d40>
# gc: collectable <cython_function_or_method 0x13c173e10>
# gc: collectable <dict 0x13c175200>
# gc: collectable <pyarrow._fs.__Pyx_EnumMeta 0x7fdb894a0c80>
# gc: collectable <getset_descriptor 0x13c167a00>
# gc: collectable <tuple 0x13c175240>
# gc: collectable <collections.OrderedDict 0x13c155b40>
# gc: collectable <tuple 0x13b496700>
# gc: collectable <cython_function_or_method 0x13c176520>
# gc: collectable <cython_function_or_method 0x13c1765f0>
# gc: collectable <cython_function_or_method 0x13c1766c0>
# gc: collectable <dict 0x13c167980>
# gc: collectable <pyarrow._s3fs.__Pyx_EnumMeta 0x7fdb894a27f0>
# gc: collectable <getset_descriptor 0x13c1679c0>
# gc: collectable <tuple 0x13c178600>
# gc: collectable <collections.OrderedDict 0x13c155dc0>
# gc: collectable <list 0x13c143fc0>
# gc: collectable <Future 0x13be96370>
# gc: collectable <Condition 0x13be96dc0>
# gc: collectable <builtin_function_or_method 0x13c13fcc0>
# gc: collectable <dict 0x13c143c00>
# gc: collectable <builtin_function_or_method 0x13c1577c0>
# gc: collectable <builtin_function_or_method 0x13c14e9f0>
# gc: collectable <builtin_function_or_method 0x13c1806d0>
# gc: collectable <builtin_function_or_method 0x13c180720>
# gc: collectable <collections.deque 0x13c129ac0>
# gc: collectable <dict 0x13c143c40>
# gc: collectable <list 0x13c143e40>
# gc: collectable <list 0x13c178ac0>
# gc: collectable <method 0x13b67b540>
# gc: collectable <functools.partial 0x13c172ef0>
# gc: collectable <tuple 0x13a30fc70>
# gc: collectable <dict 0x13a35edc0>
# gc: collectable <list 0x13c542240>
# gc: collectable <list 0x13c1a8ec0>
# gc: collectable <dict 0x13c143b40>
# gc: collectable <list 0x13c167240>
# gc: collectable <list 0x13c167fc0>
# gc: collectable <dict 0x13c143ec0>
# gc: collectable <AppFuture 0x13a162970>
# gc: collectable <Condition 0x13b496910>
# gc: collectable <builtin_function_or_method 0x13c144180>
# gc: collectable <dict 0x13c181140>
# gc: collectable <builtin_function_or_method 0x13c544e50>
# gc: collectable <builtin_function_or_method 0x13c188b80>
# gc: collectable <builtin_function_or_method 0x13c188b30>
# gc: collectable <builtin_function_or_method 0x13c546ae0>
# gc: collectable <collections.deque 0x13c53cc40>
# gc: collectable <dict 0x13c1461c0>
# gc: collectable <list 0x13c191240>
# gc: collectable <list 0x13c1b3b80>
# gc: collectable <list 0x13c1b3d00>
# gc: collectable <list 0x13c18c980>
# gc: collectable <method 0x13c18cd00>
# gc: collectable <functools.partial 0x13c546b30>
# gc: collectable <tuple 0x13abc3e80>
# gc: collectable <list 0x13c1913c0>
# gc: collectable <Future 0x13b496070>
# gc: collectable <Condition 0x13b4960d0>
# gc: collectable <builtin_function_or_method 0x13c546c20>
# gc: collectable <dict 0x13c15d580>
# gc: collectable <builtin_function_or_method 0x13c546d60>
# gc: collectable <builtin_function_or_method 0x13c546db0>
# gc: collectable <builtin_function_or_method 0x13c546e00>
# gc: collectable <builtin_function_or_method 0x13c546e50>
# gc: collectable <collections.deque 0x13c53cd60>
# gc: collectable <dict 0x13c542400>
# gc: collectable <list 0x13c1786c0>
# gc: collectable <list 0x13c178100>
# gc: collectable <method 0x13c033ac0>
# gc: collectable <functools.partial 0x13c546bd0>
# gc: collectable <tuple 0x13bf31ca0>
# gc: collectable <dict 0x13c146640>
# gc: collectable <cell 0x13be969a0>
# gc: collectable <cell 0x13be96c70>
# gc: collectable <list 0x13c18c880>
# gc: collectable <list 0x13c1b3e00>
# gc: collectable <dict 0x13c143ac0>
# gc: collectable <AppFuture 0x13b496490>
# gc: collectable <Condition 0x13b625ee0>
# gc: collectable <builtin_function_or_method 0x13c168180>
# gc: collectable <dict 0x13c143d00>
# gc: collectable <builtin_function_or_method 0x13c546b80>
# gc: collectable <builtin_function_or_method 0x13c546c70>
# gc: collectable <builtin_function_or_method 0x13c546cc0>
# gc: collectable <builtin_function_or_method 0x13c546d10>
# gc: collectable <collections.deque 0x13c53cdc0>
# gc: collectable <dict 0x13c53f200>
# gc: collectable <list 0x13c143540>
# gc: collectable <list 0x13c18e140>
# gc: collectable <list 0x13c53f3c0>
# gc: collectable <list 0x13c53f400>
# gc: collectable <method 0x13c53f5c0>
# gc: collectable <functools.partial 0x13c546f40>
# gc: collectable <tuple 0x13a1ea7c0>
# gc: collectable <tuple 0x13be83980>
# gc: collectable <function 0x13c147040>
# gc: collectable <list 0x13c18c500>
# gc: collectable <Future 0x13b625d30>
# gc: collectable <Condition 0x13b625d00>
# gc: collectable <builtin_function_or_method 0x13c546f90>
# gc: collectable <dict 0x13c143c80>
# gc: collectable <builtin_function_or_method 0x13c54b1d0>
# gc: collectable <builtin_function_or_method 0x13c54b220>
# gc: collectable <builtin_function_or_method 0x13c54b270>
# gc: collectable <builtin_function_or_method 0x13c54b2c0>
# gc: collectable <collections.deque 0x13c53ce20>
# gc: collectable <dict 0x13c143d40>
# gc: collectable <list 0x1256ba4c0>
# gc: collectable <list 0x13c542c40>
# gc: collectable <method 0x13c5427c0>
# gc: collectable <functools.partial 0x13c144540>
# gc: collectable <tuple 0x13b496520>
# gc: collectable <dict 0x13c178280>
# gc: collectable <list 0x13c18c680>
# gc: collectable <list 0x13c554280>
# gc: collectable <dict 0x13c18b740>
# gc: collectable <list 0x13c5541c0>
# gc: collectable <list 0x13c5542c0>
# gc: collectable <dict 0x13c5540c0>
# gc: collectable <AppFuture 0x13b625c70>
# gc: collectable <Condition 0x13b625c40>
# gc: collectable <builtin_function_or_method 0x13c54b040>
# gc: collectable <dict 0x13c554140>
# gc: collectable <builtin_function_or_method 0x13c54b090>
# gc: collectable <builtin_function_or_method 0x13c54b180>
# gc: collectable <builtin_function_or_method 0x13c54b360>
# gc: collectable <builtin_function_or_method 0x13c54b3b0>
# gc: collectable <collections.deque 0x13c53ce80>
# gc: collectable <dict 0x13c554080>
# gc: collectable <list 0x13c554240>
# gc: collectable <list 0x13c554340>
# gc: collectable <list 0x13c5543c0>
# gc: collectable <list 0x13c554400>
# gc: collectable <method 0x13c554440>
# gc: collectable <functools.partial 0x13c54b450>
# gc: collectable <tuple 0x13b4963a0>
# gc: collectable <list 0x13c554480>
# gc: collectable <Future 0x13b625700>
# gc: collectable <Condition 0x13b625bb0>
# gc: collectable <builtin_function_or_method 0x13c54b540>
# gc: collectable <dict 0x13c18ba40>
# gc: collectable <builtin_function_or_method 0x13c54b680>
# gc: collectable <builtin_function_or_method 0x13c54b6d0>
# gc: collectable <builtin_function_or_method 0x13c54b720>
# gc: collectable <builtin_function_or_method 0x13c54b770>
# gc: collectable <collections.deque 0x13c53cee0>
# gc: collectable <dict 0x13c554180>
# gc: collectable <list 0x13c554540>
# gc: collectable <list 0x13c5545c0>
# gc: collectable <method 0x13c554500>
# gc: collectable <functools.partial 0x13c54b4f0>
# gc: collectable <tuple 0x13b6258e0>
# gc: collectable <dict 0x13c554100>
# gc: collectable <cell 0x13b496400>
# gc: collectable <cell 0x13b625b20>
# gc: collectable <list 0x13c554300>
# gc: collectable <list 0x13c554380>
# gc: collectable <dict 0x13c554780>
# gc: collectable <AppFuture 0x13b6256d0>
# gc: collectable <Condition 0x13b625940>
# gc: collectable <builtin_function_or_method 0x13c54b590>
# gc: collectable <dict 0x13c554a80>
# gc: collectable <builtin_function_or_method 0x13c54b0e0>
# gc: collectable <builtin_function_or_method 0x13c54b4a0>
# gc: collectable <builtin_function_or_method 0x13c54b5e0>
# gc: collectable <builtin_function_or_method 0x13c54b630>
# gc: collectable <collections.deque 0x13c53cf40>
# gc: collectable <dict 0x13c554a00>
# gc: collectable <list 0x13c554880>
# gc: collectable <list 0x13c554640>
# gc: collectable <list 0x13c554b00>
# gc: collectable <list 0x13c554c00>
# gc: collectable <method 0x13c554f80>
# gc: collectable <functools.partial 0x13c54b900>
# gc: collectable <tuple 0x13b496460>
# gc: collectable <tuple 0x13be8af80>
# gc: collectable <function 0x13c548700>
# gc: collectable <list 0x13c554580>
# gc: collectable <Future 0x13b6f2370>
# gc: collectable <Condition 0x13b6f2af0>
# gc: collectable <builtin_function_or_method 0x13c54b9a0>
# gc: collectable <dict 0x13c53f4c0>
# gc: collectable <builtin_function_or_method 0x13c54ba90>
# gc: collectable <builtin_function_or_method 0x13c54bae0>
# gc: collectable <builtin_function_or_method 0x13c54bb30>
# gc: collectable <builtin_function_or_method 0x13c54bb80>
# gc: collectable <collections.deque 0x13c53cfa0>
# gc: collectable <dict 0x13c53f580>
# gc: collectable <list 0x13c554900>
# gc: collectable <list 0x13c554b80>
# gc: collectable <method 0x13c5550c0>
# gc: collectable <functools.partial 0x13c54b950>
# gc: collectable <tuple 0x13b6259a0>
# gc: collectable <dict 0x13c5556c0>
# gc: collectable <list 0x13c554200>
# gc: collectable <list 0x13c555740>
# gc: collectable <dict 0x13c554700>
# gc: collectable <list 0x13c5555c0>
# gc: collectable <list 0x13c555940>
# gc: collectable <dict 0x13c555440>
# gc: collectable <AppFuture 0x13b6f2100>
# gc: collectable <Condition 0x13b6f2310>
# gc: collectable <builtin_function_or_method 0x13c54b860>
# gc: collectable <dict 0x13c555540>
# gc: collectable <builtin_function_or_method 0x13c54b130>
# gc: collectable <builtin_function_or_method 0x13c54bc20>
# gc: collectable <builtin_function_or_method 0x13c54bc70>
# gc: collectable <builtin_function_or_method 0x13c54bcc0>
# gc: collectable <collections.deque 0x13c551040>
# gc: collectable <dict 0x13c5553c0>
# gc: collectable <list 0x13c5557c0>
# gc: collectable <list 0x13c5559c0>
# gc: collectable <list 0x13c555a40>
# gc: collectable <list 0x13c555ac0>
# gc: collectable <method 0x13c555b40>
# gc: collectable <functools.partial 0x13c54bd60>
# gc: collectable <tuple 0x13b625430>
# gc: collectable <list 0x13c555bc0>
# gc: collectable <Future 0x13a3d2c70>
# gc: collectable <Condition 0x13a3d2c40>
# gc: collectable <builtin_function_or_method 0x13c54be50>
# gc: collectable <dict 0x13c5546c0>
# gc: collectable <builtin_function_or_method 0x13c54bf90>
# gc: collectable <builtin_function_or_method 0x13c54b8b0>
# gc: collectable <builtin_function_or_method 0x13c54d040>
# gc: collectable <builtin_function_or_method 0x13c54d090>
# gc: collectable <collections.deque 0x13c5510a0>
# gc: collectable <dict 0x13c555340>
# gc: collectable <list 0x13c555d40>
# gc: collectable <list 0x13c555e40>
# gc: collectable <method 0x13c555cc0>
# gc: collectable <functools.partial 0x13c54be00>
# gc: collectable <tuple 0x13b6259d0>
# gc: collectable <dict 0x13c5554c0>
# gc: collectable <cell 0x13b625b80>
# gc: collectable <cell 0x13b625550>
# gc: collectable <list 0x13c5551c0>
# gc: collectable <list 0x13c5558c0>
# gc: collectable <dict 0x13c558200>
# gc: collectable <AppFuture 0x13a3d2640>
# gc: collectable <Condition 0x13a3d2af0>
# gc: collectable <builtin_function_or_method 0x13c54bea0>
# gc: collectable <dict 0x13c558580>
# gc: collectable <builtin_function_or_method 0x13c54b9f0>
# gc: collectable <builtin_function_or_method 0x13c54bdb0>
# gc: collectable <builtin_function_or_method 0x13c54bef0>
# gc: collectable <builtin_function_or_method 0x13c54bf40>
# gc: collectable <collections.deque 0x13c551100>
# gc: collectable <dict 0x13c558500>
# gc: collectable <list 0x13c558380>
# gc: collectable <list 0x13c555f40>
# gc: collectable <list 0x13c558600>
# gc: collectable <list 0x13c558700>
# gc: collectable <method 0x13c558a80>
# gc: collectable <functools.partial 0x13c54d220>
# gc: collectable <tuple 0x13b625520>
# gc: collectable <tuple 0x13be89040>
# gc: collectable <function 0x13c182ee0>
# gc: collectable <list 0x13c555dc0>
# gc: collectable <Future 0x13a3d26a0>
# gc: collectable <Condition 0x13a3d2f10>
# gc: collectable <builtin_function_or_method 0x13c54d2c0>
# gc: collectable <dict 0x13c554e00>
# gc: collectable <builtin_function_or_method 0x13c54d3b0>
# gc: collectable <builtin_function_or_method 0x13c54d400>
# gc: collectable <builtin_function_or_method 0x13c54d450>
# gc: collectable <builtin_function_or_method 0x13c54d4a0>
# gc: collectable <collections.deque 0x13c551160>
# gc: collectable <dict 0x13c555040>
# gc: collectable <list 0x13c558400>
# gc: collectable <list 0x13c558680>
# gc: collectable <method 0x13c555640>
# gc: collectable <functools.partial 0x13c54ba40>
# gc: collectable <tuple 0x13a3d2790>
# gc: collectable <dict 0x13c555240>
# gc: collectable <dict 0x13c558100>
# gc: collectable <list 0x13c559540>
# gc: collectable <list 0x13c559440>
# gc: collectable <dict 0x13c5591c0>
# gc: collectable <AppFuture 0x13a3d2d00>
# gc: collectable <Condition 0x13a3d2820>
# gc: collectable <builtin_function_or_method 0x13c54d310>
# gc: collectable <dict 0x13c5592c0>
# gc: collectable <builtin_function_or_method 0x13c54d540>
# gc: collectable <builtin_function_or_method 0x13c54d590>
# gc: collectable <builtin_function_or_method 0x13c54d5e0>
# gc: collectable <builtin_function_or_method 0x13c54d630>
# gc: collectable <collections.deque 0x13c5511c0>
# gc: collectable <dict 0x13c559140>
# gc: collectable <list 0x13c559640>
# gc: collectable <list 0x13c5594c0>
# gc: collectable <list 0x13c5595c0>
# gc: collectable <list 0x13c559740>
# gc: collectable <method 0x13c5596c0>
# gc: collectable <functools.partial 0x13c54d6d0>
# gc: collectable <tuple 0x13b6d1ca0>
# gc: collectable <list 0x13c5597c0>
# gc: collectable <Future 0x13a3d2df0>
# gc: collectable <Condition 0x13a3d2fa0>
# gc: collectable <builtin_function_or_method 0x13c54d7c0>
# gc: collectable <dict 0x13c558080>
# gc: collectable <builtin_function_or_method 0x13c54d900>
# gc: collectable <builtin_function_or_method 0x13c54d950>
# gc: collectable <builtin_function_or_method 0x13c54d9a0>
# gc: collectable <builtin_function_or_method 0x13c54d9f0>
# gc: collectable <collections.deque 0x13c551220>
# gc: collectable <dict 0x13c559340>
# gc: collectable <list 0x13c559940>
# gc: collectable <list 0x13c559a40>
# gc: collectable <method 0x13c5598c0>
# gc: collectable <functools.partial 0x13c1a3b30>
# gc: collectable <tuple 0x13b6254f0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c54d270>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c555840>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c54df90>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c550740>
# gc: collectable <PosixPath 0x13c552460>
# gc: collectable <list 0x13c5613c0>
# gc: collectable <dict 0x13c558900>
# gc: collectable <list 0x13c561340>
# gc: collectable <PosixPath 0x13c552400>
# gc: collectable <list 0x13c561400>
# gc: collectable <list 0x13c5614c0>
# gc: collectable <dict 0x13c143380>
# gc: collectable <dict 0x13c555ec0>
# gc: collectable <list 0x13c561380>
# gc: collectable <list 0x13c561540>
# gc: collectable <dict 0x13c559240>
# gc: collectable <AppFuture 0x13b7cb430>
# gc: collectable <Condition 0x13b7cb250>
# gc: collectable <builtin_function_or_method 0x13c54d8b0>
# gc: collectable <dict 0x119d42180>
# gc: collectable <builtin_function_or_method 0x13c54dae0>
# gc: collectable <builtin_function_or_method 0x13c54db80>
# gc: collectable <builtin_function_or_method 0x13c54dbd0>
# gc: collectable <builtin_function_or_method 0x13c54dc20>
# gc: collectable <collections.deque 0x13c551280>
# gc: collectable <dict 0x13c559c40>
# gc: collectable <list 0x13c561580>
# gc: collectable <list 0x13c5615c0>
# gc: collectable <list 0x13c561640>
# gc: collectable <list 0x13c1238c0>
# gc: collectable <method 0x13c18ce80>
# gc: collectable <functools.partial 0x13c54dcc0>
# gc: collectable <tuple 0x13a3d27c0>
# gc: collectable <list 0x13c561680>
# gc: collectable <Future 0x13b7cba60>
# gc: collectable <Condition 0x13b7cba30>
# gc: collectable <builtin_function_or_method 0x13c54dd10>
# gc: collectable <dict 0x13c53f7c0>
# gc: collectable <builtin_function_or_method 0x13c54dea0>
# gc: collectable <builtin_function_or_method 0x13c54def0>
# gc: collectable <builtin_function_or_method 0x13c54df40>
# gc: collectable <builtin_function_or_method 0x13c54d1d0>
# gc: collectable <collections.deque 0x13c5512e0>
# gc: collectable <dict 0x13c53f800>
# gc: collectable <list 0x13c5616c0>
# gc: collectable <list 0x13c561700>
# gc: collectable <method 0x13c190080>
# gc: collectable <functools.partial 0x13c54dd60>
# gc: collectable <tuple 0x13a3d2670>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c54ddb0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c191cc0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c568f90>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c563040>
# gc: collectable <PosixPath 0x13c56fd00>
# gc: collectable <list 0x13c55d300>
# gc: collectable <dict 0x119dacfc0>
# gc: collectable <list 0x13c55d280>
# gc: collectable <PosixPath 0x13c56fd60>
# gc: collectable <list 0x13c55d340>
# gc: collectable <list 0x13c55d380>
# gc: collectable <dict 0x13c559840>
# gc: collectable <list 0x13c55d2c0>
# gc: collectable <list 0x13c55d400>
# gc: collectable <dict 0x13c558c00>
# gc: collectable <AppFuture 0x13b7cb700>
# gc: collectable <Condition 0x13b7cba90>
# gc: collectable <builtin_function_or_method 0x13c557040>
# gc: collectable <dict 0x13c555fc0>
# gc: collectable <builtin_function_or_method 0x13c557090>
# gc: collectable <builtin_function_or_method 0x13c557130>
# gc: collectable <builtin_function_or_method 0x13c557180>
# gc: collectable <builtin_function_or_method 0x13c5571d0>
# gc: collectable <collections.deque 0x13c551340>
# gc: collectable <dict 0x13c550900>
# gc: collectable <list 0x13c55d440>
# gc: collectable <list 0x13c55d480>
# gc: collectable <list 0x13c55d500>
# gc: collectable <list 0x13c5630c0>
# gc: collectable <method 0x13c5631c0>
# gc: collectable <functools.partial 0x13c557270>
# gc: collectable <tuple 0x13a3d2f70>
# gc: collectable <list 0x13c55d540>
# gc: collectable <Future 0x13b6c4f70>
# gc: collectable <Condition 0x13b6c4fa0>
# gc: collectable <builtin_function_or_method 0x13c5572c0>
# gc: collectable <dict 0x13c563200>
# gc: collectable <builtin_function_or_method 0x13c557450>
# gc: collectable <builtin_function_or_method 0x13c5574a0>
# gc: collectable <builtin_function_or_method 0x13c5574f0>
# gc: collectable <builtin_function_or_method 0x13c557540>
# gc: collectable <collections.deque 0x13c5513a0>
# gc: collectable <dict 0x13c563180>
# gc: collectable <list 0x13c55d580>
# gc: collectable <list 0x13c55d5c0>
# gc: collectable <method 0x13c563240>
# gc: collectable <functools.partial 0x13c557310>
# gc: collectable <tuple 0x13b7cbdf0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c557400>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c564040>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c55fef0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c55d680>
# gc: collectable <PosixPath 0x13c549e20>
# gc: collectable <list 0x13c55cdc0>
# gc: collectable <dict 0x13c53f640>
# gc: collectable <list 0x13c55cd40>
# gc: collectable <PosixPath 0x13c549dc0>
# gc: collectable <list 0x13c55ce00>
# gc: collectable <list 0x13c55ce40>
# gc: collectable <dict 0x13c559cc0>
# gc: collectable <list 0x13c55cd80>
# gc: collectable <list 0x13c55cec0>
# gc: collectable <dict 0x13c53f840>
# gc: collectable <AppFuture 0x13b6c4550>
# gc: collectable <Condition 0x13b6c4520>
# gc: collectable <builtin_function_or_method 0x13c568f40>
# gc: collectable <dict 0x13c55d8c0>
# gc: collectable <builtin_function_or_method 0x13c568e00>
# gc: collectable <builtin_function_or_method 0x13c568db0>
# gc: collectable <builtin_function_or_method 0x13c568ef0>
# gc: collectable <builtin_function_or_method 0x13c54db30>
# gc: collectable <collections.deque 0x13c551400>
# gc: collectable <dict 0x13c5633c0>
# gc: collectable <list 0x13c55cf00>
# gc: collectable <list 0x13c55cf40>
# gc: collectable <list 0x13c55cfc0>
# gc: collectable <list 0x13c55d780>
# gc: collectable <method 0x13c55d700>
# gc: collectable <functools.partial 0x13c54de00>
# gc: collectable <tuple 0x13b7cb490>
# gc: collectable <list 0x13c55cb40>
# gc: collectable <Future 0x13b6c4f10>
# gc: collectable <Condition 0x13b6c4eb0>
# gc: collectable <builtin_function_or_method 0x13c54d360>
# gc: collectable <dict 0x13c55d880>
# gc: collectable <builtin_function_or_method 0x13c55f130>
# gc: collectable <builtin_function_or_method 0x13c55f180>
# gc: collectable <builtin_function_or_method 0x13c55f1d0>
# gc: collectable <builtin_function_or_method 0x13c55f310>
# gc: collectable <collections.deque 0x13c551460>
# gc: collectable <dict 0x13c55d840>
# gc: collectable <list 0x13c558180>
# gc: collectable <list 0x13c558800>
# gc: collectable <method 0x13c55d740>
# gc: collectable <functools.partial 0x13c55ff90>
# gc: collectable <tuple 0x13b7cb730>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c55f0e0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c55ce80>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c56eef0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c55c040>
# gc: collectable <PosixPath 0x13c55ef40>
# gc: collectable <list 0x13c53fa00>
# gc: collectable <dict 0x13c55d980>
# gc: collectable <list 0x13c53f980>
# gc: collectable <PosixPath 0x13c55eee0>
# gc: collectable <list 0x13c53fa40>
# gc: collectable <list 0x13c53fa80>
# gc: collectable <dict 0x13c55d640>
# gc: collectable <list 0x13c53f9c0>
# gc: collectable <list 0x13c53fb00>
# gc: collectable <dict 0x13c563080>
# gc: collectable <AppFuture 0x13b6c4130>
# gc: collectable <Condition 0x13b6c43a0>
# gc: collectable <builtin_function_or_method 0x13c13bf40>
# gc: collectable <dict 0x13c563400>
# gc: collectable <builtin_function_or_method 0x13c5570e0>
# gc: collectable <builtin_function_or_method 0x13c5575e0>
# gc: collectable <builtin_function_or_method 0x13c557680>
# gc: collectable <builtin_function_or_method 0x13c5576d0>
# gc: collectable <collections.deque 0x13c5514c0>
# gc: collectable <dict 0x13c55da80>
# gc: collectable <list 0x13c53fb40>
# gc: collectable <list 0x13c53fb80>
# gc: collectable <list 0x13c53fc00>
# gc: collectable <list 0x13c55c380>
# gc: collectable <method 0x13c55c100>
# gc: collectable <functools.partial 0x13c557770>
# gc: collectable <tuple 0x13b6c4d90>
# gc: collectable <list 0x13c53fc40>
# gc: collectable <Future 0x13b6c43d0>
# gc: collectable <Condition 0x13b6c4310>
# gc: collectable <builtin_function_or_method 0x13c5577c0>
# gc: collectable <dict 0x13c55c240>
# gc: collectable <builtin_function_or_method 0x13c557950>
# gc: collectable <builtin_function_or_method 0x13c5579a0>
# gc: collectable <builtin_function_or_method 0x13c5579f0>
# gc: collectable <builtin_function_or_method 0x13c557a40>
# gc: collectable <collections.deque 0x13c551520>
# gc: collectable <dict 0x13c55c1c0>
# gc: collectable <list 0x13c53fc80>
# gc: collectable <list 0x13c53fcc0>
# gc: collectable <method 0x13c18eec0>
# gc: collectable <functools.partial 0x13c546810>
# gc: collectable <tuple 0x13b6c4070>
# gc: collectable <list 0x13c55c580>
# gc: collectable <list 0x13c53fd40>
# gc: collectable <list 0x13c53fac0>
# gc: collectable <dict 0x13c55c080>
# gc: collectable <list 0x13c55c340>
# gc: collectable <list 0x13c53fd00>
# gc: collectable <dict 0x119dac100>
# gc: collectable <AppFuture 0x13b6c4e50>
# gc: collectable <Condition 0x13b6c4220>
# gc: collectable <builtin_function_or_method 0x13c5578b0>
# gc: collectable <dict 0x13c558c80>
# gc: collectable <builtin_function_or_method 0x13c557360>
# gc: collectable <builtin_function_or_method 0x13c557900>
# gc: collectable <builtin_function_or_method 0x13c557810>
# gc: collectable <builtin_function_or_method 0x13c56ef90>
# gc: collectable <collections.deque 0x13c551580>
# gc: collectable <dict 0x13c55c440>
# gc: collectable <list 0x13c53fd80>
# gc: collectable <list 0x13c53fdc0>
# gc: collectable <list 0x13c53fe40>
# gc: collectable <list 0x13c558d80>
# gc: collectable <method 0x13c558d00>
# gc: collectable <functools.partial 0x13c56e090>
# gc: collectable <tuple 0x13b6c4400>
# gc: collectable <list 0x13c53fe80>
# gc: collectable <Future 0x13bf0dee0>
# gc: collectable <Condition 0x13bf0de50>
# gc: collectable <builtin_function_or_method 0x13c56e180>
# gc: collectable <dict 0x13c561600>
# gc: collectable <builtin_function_or_method 0x13c56e2c0>
# gc: collectable <builtin_function_or_method 0x13c56e310>
# gc: collectable <builtin_function_or_method 0x13c56e360>
# gc: collectable <builtin_function_or_method 0x13c56e3b0>
# gc: collectable <collections.deque 0x13c5515e0>
# gc: collectable <dict 0x13c561740>
# gc: collectable <list 0x13c53fec0>
# gc: collectable <list 0x13c53ff00>
# gc: collectable <method 0x13c542740>
# gc: collectable <functools.partial 0x13c557630>
# gc: collectable <tuple 0x13b6c4f40>
# gc: collectable <dict 0x13c55dc80>
# gc: collectable <list 0x13c53ff80>
# gc: collectable <list 0x13c53fbc0>
# gc: collectable <dict 0x13c55dcc0>
# gc: collectable <AppFuture 0x13bf0dd30>
# gc: collectable <Condition 0x13bf0d070>
# gc: collectable <builtin_function_or_method 0x13c55f2c0>
# gc: collectable <dict 0x13c55dd40>
# gc: collectable <builtin_function_or_method 0x13c55f360>
# gc: collectable <builtin_function_or_method 0x13c55f400>
# gc: collectable <builtin_function_or_method 0x13c55f450>
# gc: collectable <builtin_function_or_method 0x13c55f4a0>
# gc: collectable <collections.deque 0x13c55ee80>
# gc: collectable <dict 0x13c55dd00>
# gc: collectable <list 0x13c18ee40>
# gc: collectable <list 0x13c558b80>
# gc: collectable <list 0x13c53ffc0>
# gc: collectable <list 0x13c561880>
# gc: collectable <method 0x13c561780>
# gc: collectable <functools.partial 0x13c55f540>
# gc: collectable <tuple 0x13bf0ddf0>
# gc: collectable <list 0x13c53f180>
# gc: collectable <Future 0x13bf0d190>
# gc: collectable <Condition 0x13bf0d1c0>
# gc: collectable <builtin_function_or_method 0x13c55f590>
# gc: collectable <dict 0x13c55dec0>
# gc: collectable <builtin_function_or_method 0x13c55f720>
# gc: collectable <builtin_function_or_method 0x13c55f770>
# gc: collectable <builtin_function_or_method 0x13c55f7c0>
# gc: collectable <builtin_function_or_method 0x13c55f810>
# gc: collectable <collections.deque 0x13c55ee20>
# gc: collectable <dict 0x13c55df00>
# gc: collectable <list 0x13c1675c0>
# gc: collectable <list 0x13c18bdc0>
# gc: collectable <method 0x13c5617c0>
# gc: collectable <functools.partial 0x13c568ea0>
# gc: collectable <tuple 0x13b6c4040>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c55f5e0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c55c880>
# gc: collectable <list 0x13c596800>
# gc: collectable <list 0x13c596840>
# gc: collectable <dict 0x13c55d040>
# gc: collectable <AppFuture 0x13bf0d250>
# gc: collectable <Condition 0x13bf0dd60>
# gc: collectable <builtin_function_or_method 0x13c59df90>
# gc: collectable <dict 0x13c55d080>
# gc: collectable <builtin_function_or_method 0x13c59dea0>
# gc: collectable <builtin_function_or_method 0x13c59def0>
# gc: collectable <builtin_function_or_method 0x13c59de50>
# gc: collectable <builtin_function_or_method 0x13c59de00>
# gc: collectable <collections.deque 0x13c5521c0>
# gc: collectable <dict 0x13c55de00>
# gc: collectable <list 0x13c596880>
# gc: collectable <list 0x13c5968c0>
# gc: collectable <list 0x13c596940>
# gc: collectable <list 0x13c18bac0>
# gc: collectable <method 0x13c15d980>
# gc: collectable <functools.partial 0x13c59dd60>
# gc: collectable <tuple 0x13bf0d580>
# gc: collectable <list 0x13c596980>
# gc: collectable <Future 0x13bf0d3a0>
# gc: collectable <Condition 0x13bf0d4c0>
# gc: collectable <builtin_function_or_method 0x13c59dd10>
# gc: collectable <dict 0x13c55d0c0>
# gc: collectable <builtin_function_or_method 0x13c59db80>
# gc: collectable <builtin_function_or_method 0x13c59db30>
# gc: collectable <builtin_function_or_method 0x13c59dae0>
# gc: collectable <builtin_function_or_method 0x13c59da90>
# gc: collectable <collections.deque 0x13c552160>
# gc: collectable <dict 0x13c55d180>
# gc: collectable <list 0x13c5969c0>
# gc: collectable <list 0x13c596a00>
# gc: collectable <method 0x13c55b180>
# gc: collectable <functools.partial 0x13c59dcc0>
# gc: collectable <tuple 0x13bf0d3d0>
# gc: collectable <method 0x13c5647c0>
# gc: collectable <functools.partial 0x13c59dc20>
# gc: collectable <tuple 0x13bf0d2e0>
#            id                                        type  refcount  \
# 0  5274866432                              <class 'list'>        10
# 1  5301613952                              <class 'list'>         4
# 2  5300464000                              <class 'dict'>         7
# 3  4914683136  <class 'parsl.dataflow.futures.AppFuture'>         4
# 4  4914679872               <class 'threading.Condition'>         4
#
#                                                 repr  size
# 0                                                 []    56
# 1                                                 []    56
# 2  {'depends': [], 'executor': '_parsl_internal',...  1176
# 3  <AppFuture at 0x124f01d00 state=finished retur...    48
# 4  <Condition(<unlocked _thread.RLock object owne...    48

# %%
# create a list of files to reference
list_of_sqlite_files = [
    "./examples/data/all_cellprofiler.sqlite",
]

# %%
cytotable.convert(
    source_path="./examples/data/all_cellprofiler.sqlite",
    dest_path="./examples/data/test-result.parquet",
    dest_datatype="parquet",
    preset="cellprofiler_sqlite_pycytominer",
)
# Out:
# Reusing previously loaded Parsl configuration.
# PosixPath('/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet')

# %%
collected = gc.collect()
if gc.garbage:
    print(f"Memory leak detected: {len(gc.garbage)} objects")
    df = pd.DataFrame(
        [
            {
                "id": id(obj),
                "type": type(obj),
                "refcount": sys.getrefcount(obj),
                "repr": repr(obj),
                "size": sys.getsizeof(obj),
            }
            for obj in gc.garbage
        ]
    )

df.head()
# Out:
# Memory leak detected: 2229 objects
# gc: collectable <cell 0x1104019a0>
# gc: collectable <tuple 0x13ca101f0>
# gc: collectable <function 0x1104168b0>
# gc: collectable <cell 0x1103f4820>
# gc: collectable <tuple 0x13b689fa0>
# gc: collectable <function 0x13ca11f70>
# gc: collectable <list 0x13be7e480>
# gc: collectable <list 0x13c9e5b40>
# gc: collectable <dict 0x13bf74500>
# gc: collectable <AppFuture 0x1103f41c0>
# gc: collectable <Condition 0x1103f43d0>
# gc: collectable <builtin_function_or_method 0x13c5f6090>
# gc: collectable <dict 0x13bf4df80>
# gc: collectable <builtin_function_or_method 0x13c5f61d0>
# gc: collectable <builtin_function_or_method 0x110456450>
# gc: collectable <builtin_function_or_method 0x110456860>
# gc: collectable <builtin_function_or_method 0x110332e00>
# gc: collectable <collections.deque 0x13c5d8a60>
# gc: collectable <dict 0x13bf546c0>
# gc: collectable <list 0x13c564140>
# gc: collectable <list 0x13b6cd500>
# gc: collectable <list 0x13b6aebc0>
# gc: collectable <list 0x13abb0200>
# gc: collectable <method 0x13c5f8700>
# gc: collectable <functools.partial 0x110450130>
# gc: collectable <tuple 0x1103c41f0>
# gc: collectable <list 0x13b6ae680>
# gc: collectable <Future 0x1103f4310>
# gc: collectable <Condition 0x1103f4fa0>
# gc: collectable <builtin_function_or_method 0x110456b30>
# gc: collectable <dict 0x13bf6ef80>
# gc: collectable <builtin_function_or_method 0x110429130>
# gc: collectable <builtin_function_or_method 0x1104290e0>
# gc: collectable <builtin_function_or_method 0x110429770>
# gc: collectable <builtin_function_or_method 0x1104297c0>
# gc: collectable <collections.deque 0x13c5d87c0>
# gc: collectable <dict 0x13bf6efc0>
# gc: collectable <list 0x13b6aee00>
# gc: collectable <list 0x13b6ae3c0>
# gc: collectable <method 0x13be75180>
# gc: collectable <functools.partial 0x110429f40>
# gc: collectable <tuple 0x13ca100d0>
# gc: collectable <list 0x10e0f1e00>
# gc: collectable <dict 0x13bf6c700>
# gc: collectable <list 0x13b6cd4c0>
# gc: collectable <list 0x13b6cd680>
# gc: collectable <dict 0x13b77e9c0>
# gc: collectable <AppFuture 0x1103f4e50>
# gc: collectable <Condition 0x1103f4c40>
# gc: collectable <builtin_function_or_method 0x13c13b9f0>
# gc: collectable <dict 0x13bf6cf40>
# gc: collectable <builtin_function_or_method 0x110429ea0>
# gc: collectable <builtin_function_or_method 0x110429720>
# gc: collectable <builtin_function_or_method 0x1104293b0>
# gc: collectable <builtin_function_or_method 0x110429090>
# gc: collectable <collections.deque 0x13c5d8160>
# gc: collectable <dict 0x13b77e840>
# gc: collectable <list 0x13c53f600>
# gc: collectable <list 0x1103da280>
# gc: collectable <list 0x13b6ae180>
# gc: collectable <list 0x13c53f280>
# gc: collectable <method 0x13c55c8c0>
# gc: collectable <functools.partial 0x13c59d810>
# gc: collectable <tuple 0x119983970>
# gc: collectable <list 0x13b6ae2c0>
# gc: collectable <Future 0x110468a00>
# gc: collectable <Condition 0x110468b80>
# gc: collectable <builtin_function_or_method 0x110429220>
# gc: collectable <dict 0x13b781c80>
# gc: collectable <builtin_function_or_method 0x110429b80>
# gc: collectable <builtin_function_or_method 0x110429f90>
# gc: collectable <builtin_function_or_method 0x110429900>
# gc: collectable <builtin_function_or_method 0x110429a90>
# gc: collectable <collections.deque 0x13c5d8640>
# gc: collectable <dict 0x13b7819c0>
# gc: collectable <list 0x13b6ae9c0>
# gc: collectable <list 0x13b6aee80>
# gc: collectable <list 0x13b6aeb00>
# gc: collectable <method 0x13c53f100>
# gc: collectable <functools.partial 0x13c59dbd0>
# gc: collectable <tuple 0x11038c490>
# gc: collectable <list 0x13be7d040>
# gc: collectable <dict 0x13b781b80>
# gc: collectable <AppFuture 0x110468ee0>
# gc: collectable <Condition 0x110468f10>
# gc: collectable <builtin_function_or_method 0x1104292c0>
# gc: collectable <dict 0x13b7815c0>
# gc: collectable <builtin_function_or_method 0x110429bd0>
# gc: collectable <builtin_function_or_method 0x110429950>
# gc: collectable <builtin_function_or_method 0x1104298b0>
# gc: collectable <builtin_function_or_method 0x110429590>
# gc: collectable <collections.deque 0x13c5d8460>
# gc: collectable <dict 0x13bf543c0>
# gc: collectable <list 0x13b6aec00>
# gc: collectable <list 0x13b6ae440>
# gc: collectable <list 0x13b6aef00>
# gc: collectable <list 0x13c5ee2c0>
# gc: collectable <method 0x13c555800>
# gc: collectable <functools.partial 0x110429ae0>
# gc: collectable <tuple 0x13bf0d790>
# gc: collectable <list 0x13b6aef80>
# gc: collectable <Future 0x110443ee0>
# gc: collectable <Condition 0x110443340>
# gc: collectable <builtin_function_or_method 0x1104294f0>
# gc: collectable <dict 0x13b781f80>
# gc: collectable <builtin_function_or_method 0x110429a40>
# gc: collectable <builtin_function_or_method 0x1104299f0>
# gc: collectable <builtin_function_or_method 0x1102f5ea0>
# gc: collectable <builtin_function_or_method 0x1102f59f0>
# gc: collectable <collections.deque 0x13c5d8700>
# gc: collectable <dict 0x13bf54540>
# gc: collectable <list 0x13b6ae880>
# gc: collectable <list 0x13b6aee40>
# gc: collectable <method 0x13bf54680>
# gc: collectable <functools.partial 0x110429680>
# gc: collectable <tuple 0x13b499d00>
# gc: collectable <dict 0x13b6b5cc0>
# gc: collectable <cell 0x110443be0>
# gc: collectable <cell 0x110443fd0>
# gc: collectable <list 0x13abb3980>
# gc: collectable <list 0x13b6aed80>
# gc: collectable <dict 0x13b781bc0>
# gc: collectable <AppFuture 0x110443cd0>
# gc: collectable <Condition 0x1104435b0>
# gc: collectable <builtin_function_or_method 0x1104296d0>
# gc: collectable <dict 0x13bf54140>
# gc: collectable <builtin_function_or_method 0x110429630>
# gc: collectable <builtin_function_or_method 0x1104295e0>
# gc: collectable <builtin_function_or_method 0x110420a40>
# gc: collectable <builtin_function_or_method 0x110420a90>
# gc: collectable <collections.deque 0x13c5d83a0>
# gc: collectable <dict 0x13bf54300>
# gc: collectable <list 0x13b6ae780>
# gc: collectable <list 0x13b6ae580>
# gc: collectable <list 0x13b4a0380>
# gc: collectable <list 0x13bf54500>
# gc: collectable <method 0x13bf57bc0>
# gc: collectable <functools.partial 0x1104207c0>
# gc: collectable <tuple 0x13bf0d760>
# gc: collectable <tuple 0x13c5f8fc0>
# gc: collectable <function 0x13b7b2430>
# gc: collectable <dict 0x13bf57ec0>
# gc: collectable <cell 0x110443910>
# gc: collectable <cell 0x110443130>
# gc: collectable <list 0x13b785640>
# gc: collectable <list 0x11a11c900>
# gc: collectable <dict 0x13bf57fc0>
# gc: collectable <AppFuture 0x110443f10>
# gc: collectable <Condition 0x1104437c0>
# gc: collectable <builtin_function_or_method 0x1104209f0>
# gc: collectable <dict 0x13bf57b80>
# gc: collectable <builtin_function_or_method 0x110420680>
# gc: collectable <builtin_function_or_method 0x1104206d0>
# gc: collectable <builtin_function_or_method 0x110420b30>
# gc: collectable <builtin_function_or_method 0x110420400>
# gc: collectable <collections.deque 0x13c5d86a0>
# gc: collectable <dict 0x13bf57d40>
# gc: collectable <list 0x13abb6c00>
# gc: collectable <list 0x13b7850c0>
# gc: collectable <list 0x13b786b80>
# gc: collectable <list 0x13bf57980>
# gc: collectable <method 0x13bf57840>
# gc: collectable <functools.partial 0x110420540>
# gc: collectable <tuple 0x1103f8be0>
# gc: collectable <tuple 0x13c5fa300>
# gc: collectable <function 0x13c58ae50>
# gc: collectable <dict 0x13bf57a80>
# gc: collectable <cell 0x110443a90>
# gc: collectable <cell 0x1104438e0>
# gc: collectable <list 0x13bf54240>
# gc: collectable <list 0x13b785c40>
# gc: collectable <dict 0x13bf57640>
# gc: collectable <AppFuture 0x110443d60>
# gc: collectable <Condition 0x1104437f0>
# gc: collectable <builtin_function_or_method 0x1104204f0>
# gc: collectable <dict 0x13bf577c0>
# gc: collectable <builtin_function_or_method 0x110420590>
# gc: collectable <builtin_function_or_method 0x1104205e0>
# gc: collectable <builtin_function_or_method 0x1104204a0>
# gc: collectable <builtin_function_or_method 0x1104203b0>
# gc: collectable <collections.deque 0x13c5d8520>
# gc: collectable <dict 0x13bf57900>
# gc: collectable <list 0x13b786200>
# gc: collectable <list 0x13b786e40>
# gc: collectable <cell 0x110443070>
# gc: collectable <cell 0x110443520>
# gc: collectable <cell 0x110443100>
# gc: collectable <cell 0x1104430d0>
# gc: collectable <cell 0x1104436a0>
# gc: collectable <tuple 0x13bf1a130>
# gc: collectable <function 0x13c58ad30>
# gc: collectable <list 0x13b7823c0>
# gc: collectable <list 0x13bf57700>
# gc: collectable <method 0x13bf57240>
# gc: collectable <functools.partial 0x13c59d9f0>
# gc: collectable <tuple 0x13ca10130>
# gc: collectable <tuple 0x13c5fa2c0>
# gc: collectable <function 0x13c58aca0>
# gc: collectable <tuple 0x13c5fa3c0>
# gc: collectable <function 0x13c58ac10>
# gc: collectable <method 0x13b785140>
# gc: collectable <functools.partial 0x110420630>
# gc: collectable <tuple 0x13ca10340>
# gc: collectable <PosixPath 0x13c5d8be0>
# gc: collectable <list 0x13b786c80>
# gc: collectable <list 0x13bf540c0>
# gc: collectable <Future 0x110426730>
# gc: collectable <Condition 0x110426b20>
# gc: collectable <builtin_function_or_method 0x110420770>
# gc: collectable <dict 0x13bf74540>
# gc: collectable <builtin_function_or_method 0x110420f40>
# gc: collectable <builtin_function_or_method 0x110420d60>
# gc: collectable <builtin_function_or_method 0x110420db0>
# gc: collectable <builtin_function_or_method 0x110420bd0>
# gc: collectable <collections.deque 0x13c5d8b80>
# gc: collectable <dict 0x13bf6c900>
# gc: collectable <list 0x13bf57cc0>
# gc: collectable <list 0x13c178240>
# gc: collectable <method 0x13b781940>
# gc: collectable <functools.partial 0x13c59df40>
# gc: collectable <tuple 0x13ca10190>
# gc: collectable <list 0x13c185cc0>
# gc: collectable <list 0x13a6b7280>
# gc: collectable <PosixPath 0x13c5d8b20>
# gc: collectable <dict 0x13b781400>
# gc: collectable <dict 0x13bf57100>
# gc: collectable <list 0x13be75040>
# gc: collectable <list 0x13be7e180>
# gc: collectable <PosixPath 0x13c5d8dc0>
# gc: collectable <dict 0x13bf72280>
# gc: collectable <list 0x13be7e700>
# gc: collectable <list 0x13c5638c0>
# gc: collectable <PosixPath 0x13c5d8e20>
# gc: collectable <dict 0x13bf722c0>
# gc: collectable <list 0x13c563900>
# gc: collectable <list 0x13c563940>
# gc: collectable <PosixPath 0x13c5d81c0>
# gc: collectable <dict 0x13bf72d40>
# gc: collectable <list 0x13be750c0>
# gc: collectable <Future 0x11045c460>
# gc: collectable <Condition 0x11045c4f0>
# gc: collectable <builtin_function_or_method 0x110420c70>
# gc: collectable <dict 0x13bf57080>
# gc: collectable <builtin_function_or_method 0x110420040>
# gc: collectable <builtin_function_or_method 0x110420090>
# gc: collectable <builtin_function_or_method 0x1104200e0>
# gc: collectable <builtin_function_or_method 0x110420130>
# gc: collectable <collections.deque 0x13c5d84c0>
# gc: collectable <dict 0x13b781e80>
# gc: collectable <list 0x13c563840>
# gc: collectable <list 0x13ca1aa80>
# gc: collectable <list 0x13ca1ab00>
# gc: collectable <Future 0x11045c0a0>
# gc: collectable <Condition 0x11045c250>
# gc: collectable <builtin_function_or_method 0x110420270>
# gc: collectable <dict 0x13b781d00>
# gc: collectable <builtin_function_or_method 0x11043d0e0>
# gc: collectable <builtin_function_or_method 0x11043d090>
# gc: collectable <builtin_function_or_method 0x11043d220>
# gc: collectable <builtin_function_or_method 0x11043d180>
# gc: collectable <collections.deque 0x13c5d8c40>
# gc: collectable <dict 0x13bf72480>
# gc: collectable <list 0x13c563880>
# gc: collectable <list 0x13c558e00>
# gc: collectable <list 0x13c558f80>
# gc: collectable <method 0x13c55c9c0>
# gc: collectable <functools.partial 0x110420220>
# gc: collectable <tuple 0x13ca10520>
# gc: collectable <dict 0x13bf72a80>
# gc: collectable <list 0x13c559dc0>
# gc: collectable <list 0x13bf72c80>
# gc: collectable <list 0x13c558cc0>
# gc: collectable <cell 0x1104269d0>
# gc: collectable <cell 0x110468910>
# gc: collectable <cell 0x11045c130>
# gc: collectable <cell 0x11045c280>
# gc: collectable <cell 0x11045c190>
# gc: collectable <tuple 0x13ca08cc0>
# gc: collectable <function 0x13c58ab80>
# gc: collectable <dict 0x13bf573c0>
# gc: collectable <list 0x13c5586c0>
# gc: collectable <list 0x13c55d100>
# gc: collectable <dict 0x13bf57380>
# gc: collectable <AppFuture 0x11045c490>
# gc: collectable <Condition 0x11045c160>
# gc: collectable <builtin_function_or_method 0x110420810>
# gc: collectable <dict 0x13bf69880>
# gc: collectable <builtin_function_or_method 0x1104202c0>
# gc: collectable <builtin_function_or_method 0x110420ef0>
# gc: collectable <builtin_function_or_method 0x1104201d0>
# gc: collectable <builtin_function_or_method 0x11043d130>
# gc: collectable <collections.deque 0x13c5d8d00>
# gc: collectable <dict 0x13bf72ac0>
# gc: collectable <list 0x13c558240>
# gc: collectable <list 0x13c550d00>
# gc: collectable <list 0x13c1857c0>
# gc: collectable <list 0x13bf720c0>
# gc: collectable <method 0x13bf72800>
# gc: collectable <functools.partial 0x11043dc70>
# gc: collectable <tuple 0x13ca10760>
# gc: collectable <list 0x11a12cc00>
# gc: collectable <Future 0x11045c3d0>
# gc: collectable <Condition 0x11045c3a0>
# gc: collectable <builtin_function_or_method 0x11043de50>
# gc: collectable <dict 0x13bf725c0>
# gc: collectable <builtin_function_or_method 0x11043d540>
# gc: collectable <builtin_function_or_method 0x11043d450>
# gc: collectable <builtin_function_or_method 0x11043d590>
# gc: collectable <builtin_function_or_method 0x11043d4f0>
# gc: collectable <collections.deque 0x13c5d8ca0>
# gc: collectable <dict 0x13bf72540>
# gc: collectable <list 0x13c185bc0>
# gc: collectable <list 0x13c555500>
# gc: collectable <method 0x13bf72c40>
# gc: collectable <functools.partial 0x110420b80>
# gc: collectable <tuple 0x13a7d3b20>
# gc: collectable <list 0x13c185ec0>
# gc: collectable <dict 0x13be75a40>
# gc: collectable <dict 0x13bf72640>
# gc: collectable <list 0x1103e2840>
# gc: collectable <list 0x13c550ec0>
# gc: collectable <dict 0x13c191a00>
# gc: collectable <AppFuture 0x11045c0d0>
# gc: collectable <Condition 0x11045c2e0>
# gc: collectable <builtin_function_or_method 0x13c5535e0>
# gc: collectable <dict 0x13c564e40>
# gc: collectable <builtin_function_or_method 0x11043d720>
# gc: collectable <builtin_function_or_method 0x11043dc20>
# gc: collectable <builtin_function_or_method 0x11043d1d0>
# gc: collectable <builtin_function_or_method 0x11043d2c0>
# gc: collectable <collections.deque 0x13c5d8880>
# gc: collectable <dict 0x13bf64040>
# gc: collectable <list 0x13c5580c0>
# gc: collectable <list 0x13c558ac0>
# gc: collectable <list 0x13c563a40>
# gc: collectable <list 0x13bf642c0>
# gc: collectable <method 0x13bf64080>
# gc: collectable <functools.partial 0x110350540>
# gc: collectable <tuple 0x13bebcbb0>
# gc: collectable <list 0x13c563a00>
# gc: collectable <Future 0x11045c9d0>
# gc: collectable <Condition 0x11045c8e0>
# gc: collectable <builtin_function_or_method 0x110350950>
# gc: collectable <dict 0x13bf64380>
# gc: collectable <builtin_function_or_method 0x110350680>
# gc: collectable <builtin_function_or_method 0x11045b7c0>
# gc: collectable <builtin_function_or_method 0x11045b810>
# gc: collectable <builtin_function_or_method 0x11045b630>
# gc: collectable <collections.deque 0x13c5d8820>
# gc: collectable <dict 0x13bf64200>
# gc: collectable <list 0x13c185e40>
# gc: collectable <list 0x13ca0f500>
# gc: collectable <method 0x13bf643c0>
# gc: collectable <functools.partial 0x1103503b0>
# gc: collectable <tuple 0x13bebcb50>
# gc: collectable <list 0x13bf64a00>
# gc: collectable <dict 0x13b4ff0c0>
# gc: collectable <dict 0x13bf724c0>
# gc: collectable <list 0x13bf57600>
# gc: collectable <list 0x13bf64400>
# gc: collectable <dict 0x13bf640c0>
# gc: collectable <AppFuture 0x11045c070>
# gc: collectable <Condition 0x11045c850>
# gc: collectable <builtin_function_or_method 0x1103504a0>
# gc: collectable <dict 0x13bf72980>
# gc: collectable <builtin_function_or_method 0x1103501d0>
# gc: collectable <builtin_function_or_method 0x110350590>
# gc: collectable <builtin_function_or_method 0x11045b4f0>
# gc: collectable <builtin_function_or_method 0x11045b540>
# gc: collectable <collections.deque 0x13c5d8e80>
# gc: collectable <dict 0x13bf72840>
# gc: collectable <list 0x13bf64140>
# gc: collectable <list 0x13bf64b40>
# gc: collectable <list 0x13bf64a40>
# gc: collectable <list 0x13bf64a80>
# gc: collectable <method 0x13bf64900>
# gc: collectable <functools.partial 0x11045b130>
# gc: collectable <tuple 0x13ca10580>
# gc: collectable <list 0x13bf64d40>
# gc: collectable <Future 0x11045c760>
# gc: collectable <Condition 0x11045c790>
# gc: collectable <builtin_function_or_method 0x11045b040>
# gc: collectable <dict 0x13bf648c0>
# gc: collectable <builtin_function_or_method 0x11045b2c0>
# gc: collectable <builtin_function_or_method 0x11045b090>
# gc: collectable <builtin_function_or_method 0x11045b360>
# gc: collectable <builtin_function_or_method 0x11045b3b0>
# gc: collectable <collections.deque 0x13c5d8f40>
# gc: collectable <dict 0x13bf64dc0>
# gc: collectable <list 0x13bf64d00>
# gc: collectable <list 0x13bf64600>
# gc: collectable <method 0x13bf64f00>
# gc: collectable <functools.partial 0x13c59d9a0>
# gc: collectable <tuple 0x13ca10c40>
# gc: collectable <list 0x13bf64e40>
# gc: collectable <dict 0x13bf64e80>
# gc: collectable <dict 0x13bf64740>
# gc: collectable <list 0x13c563340>
# gc: collectable <list 0x13bf64b80>
# gc: collectable <dict 0x13bf64c80>
# gc: collectable <AppFuture 0x11045c550>
# gc: collectable <Condition 0x11045c610>
# gc: collectable <builtin_function_or_method 0x11045b180>
# gc: collectable <dict 0x13bf64300>
# gc: collectable <builtin_function_or_method 0x11045b220>
# gc: collectable <builtin_function_or_method 0x11045b270>
# gc: collectable <builtin_function_or_method 0x11045b450>
# gc: collectable <builtin_function_or_method 0x11045b310>
# gc: collectable <collections.deque 0x13c5d8ee0>
# gc: collectable <dict 0x13bf64440>
# gc: collectable <list 0x13bf51e00>
# gc: collectable <list 0x13bf51f40>
# gc: collectable <list 0x13bf51cc0>
# gc: collectable <list 0x13bf51900>
# gc: collectable <method 0x13bf51ac0>
# gc: collectable <functools.partial 0x11045b5e0>
# gc: collectable <tuple 0x13a7d3fa0>
# gc: collectable <list 0x13bf51880>
# gc: collectable <Future 0x11045ca90>
# gc: collectable <Condition 0x11045cc10>
# gc: collectable <builtin_function_or_method 0x11045b4a0>
# gc: collectable <dict 0x13bf51680>
# gc: collectable <builtin_function_or_method 0x11045be50>
# gc: collectable <builtin_function_or_method 0x11045bea0>
# gc: collectable <builtin_function_or_method 0x11045bcc0>
# gc: collectable <builtin_function_or_method 0x11045bd10>
# gc: collectable <collections.deque 0x13c5d8fa0>
# gc: collectable <dict 0x13bf515c0>
# gc: collectable <list 0x13bf51740>
# gc: collectable <list 0x13bf51340>
# gc: collectable <method 0x13bf516c0>
# gc: collectable <functools.partial 0x110420cc0>
# gc: collectable <tuple 0x13ca106d0>
# gc: collectable <list 0x13bf51380>
# gc: collectable <dict 0x13bf51700>
# gc: collectable <list 0x13b77fb40>
# gc: collectable <list 0x13bf64340>
# gc: collectable <dict 0x13bf51480>
# gc: collectable <list 0x13bf51e40>
# gc: collectable <list 0x13b77ff40>
# gc: collectable <dict 0x13bf51500>
# gc: collectable <AppFuture 0x11045cca0>
# gc: collectable <Condition 0x11045ce50>
# gc: collectable <builtin_function_or_method 0x11045b6d0>
# gc: collectable <dict 0x13bf64c00>
# gc: collectable <builtin_function_or_method 0x11045b860>
# gc: collectable <builtin_function_or_method 0x11045b770>
# gc: collectable <builtin_function_or_method 0x11045bb80>
# gc: collectable <builtin_function_or_method 0x11045b8b0>
# gc: collectable <collections.deque 0x13c5a5040>
# gc: collectable <dict 0x13bf64780>
# gc: collectable <list 0x13b77fec0>
# gc: collectable <list 0x13b77ff80>
# gc: collectable <list 0x13b77fb00>
# gc: collectable <list 0x13b77fa80>
# gc: collectable <method 0x13b77f900>
# gc: collectable <functools.partial 0x11045b950>
# gc: collectable <tuple 0x13a697040>
# gc: collectable <list 0x13b77f780>
# gc: collectable <Future 0x11045cd30>
# gc: collectable <Condition 0x110474100>
# gc: collectable <builtin_function_or_method 0x11045ba40>
# gc: collectable <dict 0x13b77fb80>
# gc: collectable <builtin_function_or_method 0x11045bae0>
# gc: collectable <builtin_function_or_method 0x11045bd60>
# gc: collectable <builtin_function_or_method 0x11045bdb0>
# gc: collectable <builtin_function_or_method 0x11045bc70>
# gc: collectable <collections.deque 0x13c5a50a0>
# gc: collectable <dict 0x13b77f680>
# gc: collectable <list 0x13b77f940>
# gc: collectable <list 0x13b77fd80>
# gc: collectable <method 0x13b77f640>
# gc: collectable <functools.partial 0x11045b9f0>
# gc: collectable <tuple 0x13ca10220>
# gc: collectable <dict 0x13b77f8c0>
# gc: collectable <cell 0x11045caf0>
# gc: collectable <cell 0x11045c820>
# gc: collectable <list 0x13bf51d40>
# gc: collectable <list 0x13b77fe80>
# gc: collectable <dict 0x13b77f880>
# gc: collectable <AppFuture 0x1104741c0>
# gc: collectable <Condition 0x110474280>
# gc: collectable <builtin_function_or_method 0x11045ba90>
# gc: collectable <dict 0x13b77f400>
# gc: collectable <builtin_function_or_method 0x11045b9a0>
# gc: collectable <builtin_function_or_method 0x11045bbd0>
# gc: collectable <builtin_function_or_method 0x11045bc20>
# gc: collectable <builtin_function_or_method 0x11045bf40>
# gc: collectable <collections.deque 0x13c5a5100>
# gc: collectable <dict 0x13b77fd40>
# gc: collectable <list 0x13b77f380>
# gc: collectable <list 0x13b77f540>
# gc: collectable <list 0x13b77f280>
# gc: collectable <list 0x13bf5e400>
# gc: collectable <method 0x13bf5e500>
# gc: collectable <functools.partial 0x11046c040>
# gc: collectable <tuple 0x13ca102b0>
# gc: collectable <tuple 0x1103ea340>
# gc: collectable <function 0x13c58a940>
# gc: collectable <list 0x13b77fcc0>
# gc: collectable <Future 0x1104743d0>
# gc: collectable <Condition 0x110474370>
# gc: collectable <builtin_function_or_method 0x11045b1d0>
# gc: collectable <dict 0x13b4a1300>
# gc: collectable <builtin_function_or_method 0x11046c400>
# gc: collectable <builtin_function_or_method 0x11046c220>
# gc: collectable <builtin_function_or_method 0x11046c310>
# gc: collectable <builtin_function_or_method 0x11046c2c0>
# gc: collectable <collections.deque 0x13c5a5160>
# gc: collectable <dict 0x13bf5e600>
# gc: collectable <list 0x13b77f700>
# gc: collectable <list 0x1103ce200>
# gc: collectable <method 0x13bf510c0>
# gc: collectable <functools.partial 0x11045b720>
# gc: collectable <tuple 0x13ca10490>
# gc: collectable <dict 0x13bf64240>
# gc: collectable <list 0x13bf61500>
# gc: collectable <list 0x13c558480>
# gc: collectable <dict 0x13bf5e5c0>
# gc: collectable <list 0x13bf61340>
# gc: collectable <list 0x13bf61680>
# gc: collectable <dict 0x13bf61240>
# gc: collectable <AppFuture 0x1104744c0>
# gc: collectable <Condition 0x110474820>
# gc: collectable <builtin_function_or_method 0x11046c130>
# gc: collectable <dict 0x13bf61080>
# gc: collectable <builtin_function_or_method 0x11046c0e0>
# gc: collectable <builtin_function_or_method 0x11046c6d0>
# gc: collectable <builtin_function_or_method 0x11046c360>
# gc: collectable <builtin_function_or_method 0x11046c270>
# gc: collectable <collections.deque 0x13c5a51c0>
# gc: collectable <dict 0x13bf61300>
# gc: collectable <list 0x13bf61800>
# gc: collectable <list 0x13bf61540>
# gc: collectable <list 0x13bf61440>
# gc: collectable <list 0x13bf61a00>
# gc: collectable <method 0x13bf61840>
# gc: collectable <functools.partial 0x11046c4a0>
# gc: collectable <tuple 0x110401cd0>
# gc: collectable <list 0x13bf61a80>
# gc: collectable <Future 0x110474160>
# gc: collectable <Condition 0x110474040>
# gc: collectable <builtin_function_or_method 0x11046c720>
# gc: collectable <dict 0x13bf51780>
# gc: collectable <builtin_function_or_method 0x11046c540>
# gc: collectable <builtin_function_or_method 0x11046c4f0>
# gc: collectable <builtin_function_or_method 0x11046c810>
# gc: collectable <builtin_function_or_method 0x11046c770>
# gc: collectable <collections.deque 0x13c5a5220>
# gc: collectable <dict 0x13bf614c0>
# gc: collectable <list 0x13bf61880>
# gc: collectable <list 0x13bf61c80>
# gc: collectable <method 0x13bf61b00>
# gc: collectable <functools.partial 0x110429db0>
# gc: collectable <tuple 0x13ca104f0>
# gc: collectable <dict 0x13bf61200>
# gc: collectable <cell 0x110474550>
# gc: collectable <cell 0x1104740d0>
# gc: collectable <list 0x13bf61780>
# gc: collectable <list 0x13bf613c0>
# gc: collectable <dict 0x13bf5ff00>
# gc: collectable <AppFuture 0x1104746d0>
# gc: collectable <Condition 0x1104747c0>
# gc: collectable <builtin_function_or_method 0x11046c680>
# gc: collectable <dict 0x13bf5f100>
# gc: collectable <builtin_function_or_method 0x11046c5e0>
# gc: collectable <builtin_function_or_method 0x11046c450>
# gc: collectable <builtin_function_or_method 0x11046c590>
# gc: collectable <builtin_function_or_method 0x11046c630>
# gc: collectable <collections.deque 0x13c5a5280>
# gc: collectable <dict 0x13bf5f580>
# gc: collectable <list 0x13bf5f800>
# gc: collectable <list 0x13bf5ff40>
# gc: collectable <list 0x13be7fec0>
# gc: collectable <list 0x13be7fdc0>
# gc: collectable <method 0x13be7f700>
# gc: collectable <functools.partial 0x11046c860>
# gc: collectable <tuple 0x13ca105e0>
# gc: collectable <tuple 0x1103d9380>
# gc: collectable <function 0x13c58a820>
# gc: collectable <list 0x13bf61d40>
# gc: collectable <Future 0x110474790>
# gc: collectable <Condition 0x1104746a0>
# gc: collectable <builtin_function_or_method 0x11046cb80>
# gc: collectable <dict 0x13bf5e8c0>
# gc: collectable <builtin_function_or_method 0x11046ca90>
# gc: collectable <builtin_function_or_method 0x11046c9a0>
# gc: collectable <builtin_function_or_method 0x11046c900>
# gc: collectable <builtin_function_or_method 0x11046cc70>
# gc: collectable <collections.deque 0x13c5a52e0>
# gc: collectable <dict 0x13bf5e880>
# gc: collectable <list 0x13bf5f740>
# gc: collectable <list 0x13be7ff40>
# gc: collectable <method 0x13bf61ac0>
# gc: collectable <functools.partial 0x11046cae0>
# gc: collectable <tuple 0x13ca108e0>
# gc: collectable <dict 0x13bf617c0>
# gc: collectable <list 0x13bf619c0>
# gc: collectable <list 0x13be82980>
# gc: collectable <dict 0x13bf5f200>
# gc: collectable <list 0x13be82a80>
# gc: collectable <list 0x13be82680>
# gc: collectable <dict 0x13be82fc0>
# gc: collectable <AppFuture 0x13bf0d7c0>
# gc: collectable <Condition 0x13bf0d850>
# gc: collectable <builtin_function_or_method 0x11046c8b0>
# gc: collectable <dict 0x13be82e40>
# gc: collectable <builtin_function_or_method 0x11046c950>
# gc: collectable <builtin_function_or_method 0x11046c9f0>
# gc: collectable <builtin_function_or_method 0x11046cc20>
# gc: collectable <builtin_function_or_method 0x13c9ef4f0>
# gc: collectable <collections.deque 0x13c5a5340>
# gc: collectable <dict 0x13be7f340>
# gc: collectable <list 0x13be82f00>
# gc: collectable <list 0x13be82300>
# gc: collectable <list 0x13be82440>
# gc: collectable <list 0x13be83e00>
# gc: collectable <method 0x13be83d00>
# gc: collectable <functools.partial 0x13c19d7c0>
# gc: collectable <tuple 0x13ca10670>
# gc: collectable <list 0x13be83b80>
# gc: collectable <Future 0x110432910>
# gc: collectable <Condition 0x1104325b0>
# gc: collectable <builtin_function_or_method 0x13ca08f40>
# gc: collectable <dict 0x13bf5f240>
# gc: collectable <builtin_function_or_method 0x13c166e50>
# gc: collectable <builtin_function_or_method 0x110462040>
# gc: collectable <builtin_function_or_method 0x110462090>
# gc: collectable <builtin_function_or_method 0x1104620e0>
# gc: collectable <collections.deque 0x13c5a53a0>
# gc: collectable <dict 0x13be82c00>
# gc: collectable <list 0x13be83ac0>
# gc: collectable <list 0x13be83800>
# gc: collectable <method 0x13be83a40>
# gc: collectable <functools.partial 0x11046ca40>
# gc: collectable <tuple 0x13ca10940>
# gc: collectable <dict 0x13be7f780>
# gc: collectable <cell 0x110474850>
# gc: collectable <cell 0x110474610>
# gc: collectable <list 0x13be82640>
# gc: collectable <list 0x13be821c0>
# gc: collectable <dict 0x13be83480>
# gc: collectable <AppFuture 0x110432ac0>
# gc: collectable <Condition 0x1104328e0>
# gc: collectable <builtin_function_or_method 0x13c19df40>
# gc: collectable <dict 0x13be85e40>
# gc: collectable <builtin_function_or_method 0x13c19d810>
# gc: collectable <builtin_function_or_method 0x13ca08ea0>
# gc: collectable <builtin_function_or_method 0x13ca08f90>
# gc: collectable <builtin_function_or_method 0x13ca08ef0>
# gc: collectable <collections.deque 0x13c5a5400>
# gc: collectable <dict 0x13be8ab40>
# gc: collectable <list 0x13be830c0>
# gc: collectable <list 0x13be83280>
# gc: collectable <list 0x13be85f00>
# gc: collectable <list 0x13be85c00>
# gc: collectable <method 0x13be85280>
# gc: collectable <functools.partial 0x110462270>
# gc: collectable <tuple 0x13ca10c70>
# gc: collectable <tuple 0x1103d6580>
# gc: collectable <function 0x13c58a700>
# gc: collectable <list 0x13be83940>
# gc: collectable <Future 0x110432760>
# gc: collectable <Condition 0x110432f40>
# gc: collectable <builtin_function_or_method 0x110462310>
# gc: collectable <dict 0x13be7fd00>
# gc: collectable <builtin_function_or_method 0x110462400>
# gc: collectable <builtin_function_or_method 0x110462450>
# gc: collectable <builtin_function_or_method 0x1104624a0>
# gc: collectable <builtin_function_or_method 0x1104624f0>
# gc: collectable <collections.deque 0x13c5a5460>
# gc: collectable <dict 0x13be7f8c0>
# gc: collectable <list 0x13be94040>
# gc: collectable <list 0x13be85e00>
# gc: collectable <method 0x13be85100>
# gc: collectable <functools.partial 0x11046c090>
# gc: collectable <tuple 0x13c063940>
# gc: collectable <dict 0x13be7f640>
# gc: collectable <list 0x13be828c0>
# gc: collectable <list 0x13be89380>
# gc: collectable <dict 0x13be83380>
# gc: collectable <list 0x13be89880>
# gc: collectable <list 0x13be890c0>
# gc: collectable <dict 0x13be89f00>
# gc: collectable <AppFuture 0x1104327f0>
# gc: collectable <Condition 0x110432dc0>
# gc: collectable <builtin_function_or_method 0x1104621d0>
# gc: collectable <dict 0x13be89ac0>
# gc: collectable <builtin_function_or_method 0x110462360>
# gc: collectable <builtin_function_or_method 0x110462590>
# gc: collectable <builtin_function_or_method 0x1104625e0>
# gc: collectable <builtin_function_or_method 0x110462630>
# gc: collectable <collections.deque 0x13c5a54c0>
# gc: collectable <dict 0x13be89e80>
# gc: collectable <list 0x13a681780>
# gc: collectable <list 0x13a681800>
# gc: collectable <list 0x13c5426c0>
# gc: collectable <list 0x13c5425c0>
# gc: collectable <method 0x13c542640>
# gc: collectable <functools.partial 0x1104626d0>
# gc: collectable <tuple 0x13ca10a90>
# gc: collectable <list 0x13c542680>
# gc: collectable <Future 0x110432d30>
# gc: collectable <Condition 0x110432d60>
# gc: collectable <builtin_function_or_method 0x1104627c0>
# gc: collectable <dict 0x13be83840>
# gc: collectable <builtin_function_or_method 0x110462900>
# gc: collectable <builtin_function_or_method 0x110462950>
# gc: collectable <builtin_function_or_method 0x1104629a0>
# gc: collectable <builtin_function_or_method 0x1104629f0>
# gc: collectable <collections.deque 0x13c5a5520>
# gc: collectable <dict 0x13be899c0>
# gc: collectable <list 0x13c542700>
# gc: collectable <list 0x13c55b500>
# gc: collectable <method 0x13c542880>
# gc: collectable <functools.partial 0x110462770>
# gc: collectable <tuple 0x13b689220>
# gc: collectable <dict 0x13be89c00>
# gc: collectable <cell 0x110432fd0>
# gc: collectable <cell 0x1104329a0>
# gc: collectable <list 0x13be89680>
# gc: collectable <list 0x13a6815c0>
# gc: collectable <dict 0x13c55b7c0>
# gc: collectable <AppFuture 0x110432f10>
# gc: collectable <Condition 0x1104328b0>
# gc: collectable <builtin_function_or_method 0x110462810>
# gc: collectable <dict 0x13c55be40>
# gc: collectable <builtin_function_or_method 0x1104622c0>
# gc: collectable <builtin_function_or_method 0x110462720>
# gc: collectable <builtin_function_or_method 0x110462860>
# gc: collectable <builtin_function_or_method 0x1104628b0>
# gc: collectable <collections.deque 0x13c5a5580>
# gc: collectable <dict 0x13c55b640>
# gc: collectable <list 0x13c55b3c0>
# gc: collectable <list 0x13c55ba80>
# gc: collectable <list 0x13c55be00>
# gc: collectable <list 0x13c55bf40>
# gc: collectable <method 0x13c5548c0>
# gc: collectable <functools.partial 0x110462b80>
# gc: collectable <tuple 0x13b6892e0>
# gc: collectable <tuple 0x13c18b900>
# gc: collectable <function 0x13c58a5e0>
# gc: collectable <list 0x13c55b700>
# gc: collectable <Future 0x13ac92eb0>
# gc: collectable <Condition 0x13ac92ac0>
# gc: collectable <builtin_function_or_method 0x110462c20>
# gc: collectable <dict 0x13be85200>
# gc: collectable <builtin_function_or_method 0x110462d10>
# gc: collectable <builtin_function_or_method 0x110462d60>
# gc: collectable <builtin_function_or_method 0x110462db0>
# gc: collectable <builtin_function_or_method 0x110462e00>
# gc: collectable <collections.deque 0x13c5a55e0>
# gc: collectable <dict 0x13be85740>
# gc: collectable <list 0x13c55b240>
# gc: collectable <list 0x13c55be80>
# gc: collectable <method 0x13be85840>
# gc: collectable <functools.partial 0x110462bd0>
# gc: collectable <tuple 0x13b689460>
# gc: collectable <dict 0x13be89d40>
# gc: collectable <dict 0x13c55b600>
# gc: collectable <list 0x13c561d40>
# gc: collectable <list 0x13c5618c0>
# gc: collectable <dict 0x13c554a40>
# gc: collectable <AppFuture 0x119c2ba00>
# gc: collectable <Condition 0x110432cd0>
# gc: collectable <builtin_function_or_method 0x110462ae0>
# gc: collectable <dict 0x13c554fc0>
# gc: collectable <builtin_function_or_method 0x110462b30>
# gc: collectable <builtin_function_or_method 0x110462ea0>
# gc: collectable <builtin_function_or_method 0x110462ef0>
# gc: collectable <builtin_function_or_method 0x110462f40>
# gc: collectable <collections.deque 0x13c5a5640>
# gc: collectable <dict 0x13c55bb40>
# gc: collectable <list 0x13c561e80>
# gc: collectable <list 0x13c561b00>
# gc: collectable <list 0x13c561dc0>
# gc: collectable <list 0x13c561040>
# gc: collectable <method 0x13c561f00>
# gc: collectable <functools.partial 0x110462220>
# gc: collectable <tuple 0x13ca10640>
# gc: collectable <list 0x13c561100>
# gc: collectable <Future 0x13b7606d0>
# gc: collectable <Condition 0x13b760760>
# gc: collectable <builtin_function_or_method 0x110462c70>
# gc: collectable <dict 0x13c561980>
# gc: collectable <builtin_function_or_method 0x11046a180>
# gc: collectable <builtin_function_or_method 0x11046a1d0>
# gc: collectable <builtin_function_or_method 0x11046a220>
# gc: collectable <builtin_function_or_method 0x11046a270>
# gc: collectable <collections.deque 0x13c5a56a0>
# gc: collectable <dict 0x13c561bc0>
# gc: collectable <list 0x13c561f40>
# gc: collectable <list 0x13c55df40>
# gc: collectable <method 0x13c55d6c0>
# gc: collectable <functools.partial 0x1104623b0>
# gc: collectable <tuple 0x13b689f70>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046a040>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13be89a00>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046af40>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x11041a780>
# gc: collectable <PosixPath 0x13ca148e0>
# gc: collectable <list 0x110448100>
# gc: collectable <dict 0x13c123c40>
# gc: collectable <list 0x1104486c0>
# gc: collectable <PosixPath 0x13ca14880>
# gc: collectable <list 0x110448440>
# gc: collectable <list 0x1104485c0>
# gc: collectable <dict 0x13bf51580>
# gc: collectable <dict 0x13c554940>
# gc: collectable <list 0x110448740>
# gc: collectable <list 0x1103e1500>
# gc: collectable <dict 0x1103d8e40>
# gc: collectable <AppFuture 0x13b760640>
# gc: collectable <Condition 0x13b760610>
# gc: collectable <builtin_function_or_method 0x11046a090>
# gc: collectable <dict 0x13c55b940>
# gc: collectable <builtin_function_or_method 0x11046a0e0>
# gc: collectable <builtin_function_or_method 0x11046a310>
# gc: collectable <builtin_function_or_method 0x11046a360>
# gc: collectable <builtin_function_or_method 0x11046a3b0>
# gc: collectable <collections.deque 0x13c5a5700>
# gc: collectable <dict 0x13c55db00>
# gc: collectable <list 0x1103e14c0>
# gc: collectable <list 0x1103e12c0>
# gc: collectable <list 0x1103e1780>
# gc: collectable <list 0x1103dcd40>
# gc: collectable <method 0x1103dcf00>
# gc: collectable <functools.partial 0x11046a450>
# gc: collectable <tuple 0x13b499ca0>
# gc: collectable <list 0x1103e1140>
# gc: collectable <Future 0x13b760670>
# gc: collectable <Condition 0x13b760520>
# gc: collectable <builtin_function_or_method 0x11046a4a0>
# gc: collectable <dict 0x1103bde40>
# gc: collectable <builtin_function_or_method 0x11046a630>
# gc: collectable <builtin_function_or_method 0x11046a680>
# gc: collectable <builtin_function_or_method 0x11046a6d0>
# gc: collectable <builtin_function_or_method 0x11046a720>
# gc: collectable <collections.deque 0x13c5a5760>
# gc: collectable <dict 0x1103bd980>
# gc: collectable <list 0x1103e1680>
# gc: collectable <list 0x1103e1740>
# gc: collectable <method 0x1103dc880>
# gc: collectable <functools.partial 0x11046a4f0>
# gc: collectable <tuple 0x13b689520>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046a540>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c564800>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046af90>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x1103de200>
# gc: collectable <PosixPath 0x13ca1c880>
# gc: collectable <list 0x1104246c0>
# gc: collectable <dict 0x1103dcd80>
# gc: collectable <list 0x110424040>
# gc: collectable <PosixPath 0x13ca1c8e0>
# gc: collectable <list 0x110424c00>
# gc: collectable <list 0x110424c80>
# gc: collectable <dict 0x13c55d9c0>
# gc: collectable <list 0x110424880>
# gc: collectable <list 0x1104247c0>
# gc: collectable <dict 0x1103dca00>
# gc: collectable <AppFuture 0x13b760400>
# gc: collectable <Condition 0x13b7603a0>
# gc: collectable <builtin_function_or_method 0x11046a590>
# gc: collectable <dict 0x110463100>
# gc: collectable <builtin_function_or_method 0x11046a5e0>
# gc: collectable <builtin_function_or_method 0x11046a810>
# gc: collectable <builtin_function_or_method 0x11046a860>
# gc: collectable <builtin_function_or_method 0x11046a8b0>
# gc: collectable <collections.deque 0x13c5a57c0>
# gc: collectable <dict 0x13c5549c0>
# gc: collectable <list 0x110424d40>
# gc: collectable <list 0x110424200>
# gc: collectable <list 0x110424b80>
# gc: collectable <list 0x1103ea7c0>
# gc: collectable <method 0x1103eafc0>
# gc: collectable <functools.partial 0x11046a950>
# gc: collectable <tuple 0x13b689dc0>
# gc: collectable <list 0x110424940>
# gc: collectable <Future 0x13b7602b0>
# gc: collectable <Condition 0x13b760280>
# gc: collectable <builtin_function_or_method 0x11046a9a0>
# gc: collectable <dict 0x110463b80>
# gc: collectable <builtin_function_or_method 0x11046ab30>
# gc: collectable <builtin_function_or_method 0x11046ab80>
# gc: collectable <builtin_function_or_method 0x11046abd0>
# gc: collectable <builtin_function_or_method 0x11046ac20>
# gc: collectable <collections.deque 0x13c5a5820>
# gc: collectable <dict 0x110463d40>
# gc: collectable <list 0x110424700>
# gc: collectable <list 0x110424480>
# gc: collectable <method 0x1103eab40>
# gc: collectable <functools.partial 0x11046a9f0>
# gc: collectable <tuple 0x13bf0d610>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046aa40>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x110428a00>
# gc: collectable <pyarrow._parquet.FileMetaData 0x11046aa90>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x110459580>
# gc: collectable <PosixPath 0x13ca17d00>
# gc: collectable <list 0x1104305c0>
# gc: collectable <dict 0x1103eaa80>
# gc: collectable <list 0x110430600>
# gc: collectable <PosixPath 0x13ca17d60>
# gc: collectable <list 0x110430580>
# gc: collectable <list 0x1104301c0>
# gc: collectable <dict 0x1104631c0>
# gc: collectable <list 0x110430cc0>
# gc: collectable <list 0x110430240>
# gc: collectable <dict 0x13c561180>
# gc: collectable <AppFuture 0x13b760850>
# gc: collectable <Condition 0x13b7600a0>
# gc: collectable <builtin_function_or_method 0x11046a130>
# gc: collectable <dict 0x11045fe00>
# gc: collectable <builtin_function_or_method 0x11046aae0>
# gc: collectable <builtin_function_or_method 0x11046ad10>
# gc: collectable <builtin_function_or_method 0x11046ad60>
# gc: collectable <builtin_function_or_method 0x11046adb0>
# gc: collectable <collections.deque 0x13c5a5880>
# gc: collectable <dict 0x1103eae80>
# gc: collectable <list 0x1104307c0>
# gc: collectable <list 0x110430940>
# gc: collectable <list 0x1103e29c0>
# gc: collectable <list 0x13bf5e900>
# gc: collectable <method 0x13bf5ec80>
# gc: collectable <functools.partial 0x11046ae50>
# gc: collectable <tuple 0x13b7605b0>
# gc: collectable <list 0x1103e2dc0>
# gc: collectable <Future 0x13b760130>
# gc: collectable <Condition 0x13b760ac0>
# gc: collectable <builtin_function_or_method 0x11046aea0>
# gc: collectable <dict 0x11045fc80>
# gc: collectable <builtin_function_or_method 0x110471090>
# gc: collectable <builtin_function_or_method 0x1104710e0>
# gc: collectable <builtin_function_or_method 0x110471130>
# gc: collectable <builtin_function_or_method 0x110471180>
# gc: collectable <collections.deque 0x13c5a58e0>
# gc: collectable <dict 0x11045f500>
# gc: collectable <list 0x1103e2f40>
# gc: collectable <list 0x1103e2c00>
# gc: collectable <method 0x13bf5ed80>
# gc: collectable <functools.partial 0x110462cc0>
# gc: collectable <tuple 0x13b760340>
# gc: collectable <pyarrow._parquet.FileMetaData 0x13c5f6860>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x1104243c0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x110471ef0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x1104244c0>
# gc: collectable <PosixPath 0x13ca22be0>
# gc: collectable <list 0x11041ac00>
# gc: collectable <dict 0x110463500>
# gc: collectable <list 0x11041a400>
# gc: collectable <PosixPath 0x13ca22c40>
# gc: collectable <list 0x11041a100>
# gc: collectable <list 0x11041a0c0>
# gc: collectable <dict 0x11045f940>
# gc: collectable <list 0x11041a080>
# gc: collectable <list 0x11041a340>
# gc: collectable <dict 0x13bf5e340>
# gc: collectable <AppFuture 0x13b7608e0>
# gc: collectable <Condition 0x13b7601f0>
# gc: collectable <builtin_function_or_method 0x110420310>
# gc: collectable <dict 0x13bf5e280>
# gc: collectable <builtin_function_or_method 0x110471f90>
# gc: collectable <builtin_function_or_method 0x110471040>
# gc: collectable <builtin_function_or_method 0x110471270>
# gc: collectable <builtin_function_or_method 0x1104712c0>
# gc: collectable <collections.deque 0x13c5a5940>
# gc: collectable <dict 0x1103ea8c0>
# gc: collectable <list 0x11041a4c0>
# gc: collectable <list 0x11041a200>
# gc: collectable <list 0x11041a680>
# gc: collectable <list 0x11045f980>
# gc: collectable <method 0x11045f240>
# gc: collectable <functools.partial 0x110471360>
# gc: collectable <tuple 0x13b7604c0>
# gc: collectable <list 0x11041ab40>
# gc: collectable <Future 0x13b712cd0>
# gc: collectable <Condition 0x13b712f40>
# gc: collectable <builtin_function_or_method 0x1104713b0>
# gc: collectable <dict 0x110463940>
# gc: collectable <builtin_function_or_method 0x110471540>
# gc: collectable <builtin_function_or_method 0x110471590>
# gc: collectable <builtin_function_or_method 0x1104715e0>
# gc: collectable <builtin_function_or_method 0x110471630>
# gc: collectable <collections.deque 0x13c5a59a0>
# gc: collectable <dict 0x110463c00>
# gc: collectable <list 0x11041a180>
# gc: collectable <list 0x11041a440>
# gc: collectable <method 0x11045ff00>
# gc: collectable <functools.partial 0x110471400>
# gc: collectable <tuple 0x13b7609d0>
# gc: collectable <list 0x11045f880>
# gc: collectable <list 0x11041a140>
# gc: collectable <list 0x11041a300>
# gc: collectable <dict 0x13bf5ef80>
# gc: collectable <list 0x11045f080>
# gc: collectable <list 0x11041a040>
# gc: collectable <dict 0x11045f3c0>
# gc: collectable <AppFuture 0x13b712c40>
# gc: collectable <Condition 0x13b712ee0>
# gc: collectable <builtin_function_or_method 0x1104714f0>
# gc: collectable <dict 0x1104598c0>
# gc: collectable <builtin_function_or_method 0x110471450>
# gc: collectable <builtin_function_or_method 0x110471720>
# gc: collectable <builtin_function_or_method 0x1104714a0>
# gc: collectable <builtin_function_or_method 0x110471770>
# gc: collectable <collections.deque 0x13c5a5a00>
# gc: collectable <dict 0x11045f7c0>
# gc: collectable <list 0x11041a1c0>
# gc: collectable <list 0x11041a280>
# gc: collectable <list 0x11041a800>
# gc: collectable <list 0x110459b00>
# gc: collectable <method 0x110459080>
# gc: collectable <functools.partial 0x110471860>
# gc: collectable <tuple 0x13b760820>
# gc: collectable <list 0x11041afc0>
# gc: collectable <Future 0x13b712f10>
# gc: collectable <Condition 0x13b712e20>
# gc: collectable <builtin_function_or_method 0x1104718b0>
# gc: collectable <dict 0x1104593c0>
# gc: collectable <builtin_function_or_method 0x110471a40>
# gc: collectable <builtin_function_or_method 0x110471a90>
# gc: collectable <builtin_function_or_method 0x110471ae0>
# gc: collectable <builtin_function_or_method 0x110471b30>
# gc: collectable <collections.deque 0x13c5a5a60>
# gc: collectable <dict 0x110459640>
# gc: collectable <list 0x11041aa40>
# gc: collectable <list 0x11041a940>
# gc: collectable <method 0x1104596c0>
# gc: collectable <functools.partial 0x110471900>
# gc: collectable <tuple 0x13b7600d0>
# gc: collectable <dict 0x110428a40>
# gc: collectable <list 0x110459e80>
# gc: collectable <list 0x11041ab80>
# gc: collectable <dict 0x1104284c0>
# gc: collectable <AppFuture 0x13b712fa0>
# gc: collectable <Condition 0x13b712970>
# gc: collectable <builtin_function_or_method 0x11046acc0>
# gc: collectable <dict 0x1103d07c0>
# gc: collectable <builtin_function_or_method 0x11046aef0>
# gc: collectable <builtin_function_or_method 0x110456b80>
# gc: collectable <builtin_function_or_method 0x1104719a0>
# gc: collectable <builtin_function_or_method 0x110471950>
# gc: collectable <collections.deque 0x13ca22040>
# gc: collectable <dict 0x110428800>
# gc: collectable <list 0x1104217c0>
# gc: collectable <list 0x11041af80>
# gc: collectable <list 0x11041ab00>
# gc: collectable <list 0x1104630c0>
# gc: collectable <method 0x13bf5eb40>
# gc: collectable <functools.partial 0x110471bd0>
# gc: collectable <tuple 0x13b712dc0>
# gc: collectable <list 0x11041ad80>
# gc: collectable <Future 0x13b712b20>
# gc: collectable <Condition 0x13b4dea60>
# gc: collectable <builtin_function_or_method 0x110471c20>
# gc: collectable <dict 0x1103d0d40>
# gc: collectable <builtin_function_or_method 0x110471db0>
# gc: collectable <builtin_function_or_method 0x110471e00>
# gc: collectable <builtin_function_or_method 0x110471e50>
# gc: collectable <builtin_function_or_method 0x110471ea0>
# gc: collectable <collections.deque 0x13ca220a0>
# gc: collectable <dict 0x1103d0440>
# gc: collectable <list 0x11041a700>
# gc: collectable <list 0x11041a8c0>
# gc: collectable <method 0x110459880>
# gc: collectable <functools.partial 0x110471c70>
# gc: collectable <tuple 0x13b712ca0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x1104717c0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x13c559040>
# gc: collectable <list 0x13ca2be80>
# gc: collectable <list 0x13ca2bec0>
# gc: collectable <dict 0x1104289c0>
# gc: collectable <AppFuture 0x13b4dea00>
# gc: collectable <Condition 0x13b4de9d0>
# gc: collectable <builtin_function_or_method 0x110471cc0>
# gc: collectable <dict 0x1103d0700>
# gc: collectable <builtin_function_or_method 0x110471220>
# gc: collectable <builtin_function_or_method 0x110471d60>
# gc: collectable <builtin_function_or_method 0x13ca23040>
# gc: collectable <builtin_function_or_method 0x13ca23090>
# gc: collectable <collections.deque 0x13ca14640>
# gc: collectable <dict 0x1103d0f40>
# gc: collectable <list 0x13ca2bf00>
# gc: collectable <list 0x13ca2bf40>
# gc: collectable <list 0x13ca2bfc0>
# gc: collectable <list 0x11041abc0>
# gc: collectable <method 0x11041a980>
# gc: collectable <functools.partial 0x13ca23130>
# gc: collectable <tuple 0x13b4dec40>
# gc: collectable <list 0x13ca30040>
# gc: collectable <Future 0x13b4deac0>
# gc: collectable <Condition 0x13b4dea90>
# gc: collectable <builtin_function_or_method 0x13ca23180>
# gc: collectable <dict 0x1103d3e00>
# gc: collectable <builtin_function_or_method 0x13ca23310>
# gc: collectable <builtin_function_or_method 0x13ca23360>
# gc: collectable <builtin_function_or_method 0x13ca233b0>
# gc: collectable <builtin_function_or_method 0x13ca23400>
# gc: collectable <collections.deque 0x13ca145e0>
# gc: collectable <dict 0x1103aeb40>
# gc: collectable <list 0x13ca30080>
# gc: collectable <list 0x13ca300c0>
# gc: collectable <method 0x11041ad40>
# gc: collectable <functools.partial 0x13ca231d0>
# gc: collectable <tuple 0x13b4deaf0>
# gc: collectable <method 0x11045f280>
# gc: collectable <functools.partial 0x13ca23270>
# gc: collectable <tuple 0x13b712d30>
# gc: collectable <cell 0x13c0b5910>
# gc: collectable <tuple 0x11039deb0>
# gc: collectable <function 0x1103acdc0>
#            id                                        type  refcount  \
# 0  5274866432                              <class 'list'>         9
# 1  5301613952                              <class 'list'>         4
# 2  5300464000                              <class 'dict'>         7
# 3  4914683136  <class 'parsl.dataflow.futures.AppFuture'>         4
# 4  4914679872               <class 'threading.Condition'>         4
#
#                                                 repr  size
# 0                                                 []    56
# 1                                                 []    56
# 2  {'depends': [], 'executor': '_parsl_internal',...  1176
# 3  <AppFuture at 0x124f01d00 state=finished retur...    48
# 4  <Condition(<unlocked _thread.RLock object owne...    48

# %%
df.sort_values(by=["size", "refcount"], ascending=False).drop_duplicates(
    subset="id"
).head(30)
# Out:
#               id            type  refcount  \
# 2     5300464000  <class 'dict'>         7
# 40    5302850560  <class 'dict'>         7
# 122   5302878464  <class 'dict'>         7
# 172   5302881664  <class 'dict'>         7
# 473   5302926976  <class 'dict'>         7
# 572   5302926016  <class 'dict'>         7
# 653   5307189120  <class 'dict'>         7
# 734   5307204096  <class 'dict'>         7
# 1127  5301028096  <class 'dict'>         7
# 1165  5292681664  <class 'dict'>         7
# 1240  5292694464  <class 'dict'>         7
# 1290  5300909632  <class 'dict'>         7
# 1598  5292685440  <class 'dict'>         7
# 1679  5300944640  <class 'dict'>         7
# 1760  5300040832  <class 'dict'>         7
# 1841  5307217856  <class 'dict'>         7
# 73    5302853248  <class 'dict'>         6
# 147   5302880640  <class 'dict'>         6
# 276   5302851968  <class 'dict'>         6
# 315   5302895232  <class 'dict'>         6
# 354   5302919680  <class 'dict'>         6
# 393   5302921152  <class 'dict'>         6
# 434   5302924288  <class 'dict'>         6
# 533   5302927040  <class 'dict'>         6
# 614   5307187392  <class 'dict'>         6
# 695   5307192384  <class 'dict'>         6
# 774   5307208128  <class 'dict'>         6
# 823   5307208256  <class 'dict'>         6
# 871   5307206656  <class 'dict'>         6
# 919   5307103296  <class 'dict'>         6
#
#                                                    repr  size
# 2     {'depends': [], 'executor': '_parsl_internal',...  1176
# 40    {'depends': [], 'executor': '_parsl_internal',...  1176
# 122   {'depends': [<AppFuture at 0x13beeb4f0 state=f...  1176
# 172   {'depends': [<AppFuture at 0x13beeb970 state=f...  1176
# 473   {'depends': [<AppFuture at 0x13abb8190 state=f...  1176
# 572   {'depends': [<AppFuture at 0x13a162970 state=f...  1176
# 653   {'depends': [<AppFuture at 0x13b625c70 state=f...  1176
# 734   {'depends': [<AppFuture at 0x13b6f2100 state=f...  1176
# 1127  {'depends': [], 'executor': '_parsl_internal',...  1176
# 1165  {'depends': [], 'executor': '_parsl_internal',...  1176
# 1240  {'depends': [<AppFuture at 0x110468ee0 state=f...  1176
# 1290  {'depends': [<AppFuture at 0x110443cd0 state=f...  1176
# 1598  {'depends': [<AppFuture at 0x11045cca0 state=f...  1176
# 1679  {'depends': [<AppFuture at 0x1104744c0 state=f...  1176
# 1760  {'depends': [<AppFuture at 0x13bf0d7c0 state=f...  1176
# 1841  {'depends': [<AppFuture at 0x1104327f0 state=f...  1176
# 73    {'depends': [], 'executor': 'local_threads', '...  1176
# 147   {'depends': [<AppFuture at 0x13beeb970 state=f...  1176
# 276   {'depends': [], 'executor': 'local_threads', '...  1176
# 315   {'depends': [], 'executor': 'local_threads', '...  1176
# 354   {'depends': [], 'executor': 'local_threads', '...  1176
# 393   {'depends': [], 'executor': 'local_threads', '...  1176
# 434   {'depends': [], 'executor': 'local_threads', '...  1176
# 533   {'depends': [], 'executor': 'local_threads', '...  1176
# 614   {'depends': [], 'executor': 'local_threads', '...  1176
# 695   {'depends': [], 'executor': 'local_threads', '...  1176
# 774   {'depends': [], 'executor': 'local_threads', '...  1176
# 823   {'depends': [], 'executor': 'local_threads', '...  1176
# 871   {'depends': [], 'executor': 'local_threads', '...  1176
# 919   {'depends': [], 'executor': 'local_threads', '...  1176

# %%
df[
    ~df["repr"].str.contains("AppFuture") & ~df["repr"].str.contains("deque")
].sort_values(by=["size", "refcount"], ascending=False).drop_duplicates(
    subset="id"
).head(
    30
).to_csv(
    "leaks.csv"
)

# %%
{
    "source_group_name": "Per_image.sqlite",
    "source": {
        "source_path": PosixPath(
            "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/all_cellprofiler.sqlite"
        ),
        "table_name": "Per_Image",
        "offsets": [0],
    },
    "chunk_size": 1000,
    "offset": 0,
    "dest_path": PosixPath(
        "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet"
    ),
    "data_type_cast_map": None,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 {
#       2     "source_group_name": "Per_image.sqlite",
#       3     "source": {
#       4         "source_path": PosixPath(
#       5             "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/all_cellprofiler.sqlite"
#       6         ),
#       7         "table_name": "Per_Image",
#       8         "offsets": [0],
#       9     },
#      10     "chunk_size": 1000,
#      11     "offset": 0,
#      12     "dest_path": PosixPath(
#      13         "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet"
#      14     ),
#      15     "data_type_cast_map": None,
#      16 }
#
# Cell In[7], line 3, in <traced_lambda>()
#       1 {
#       2     "source_group_name": "Per_image.sqlite",
# ----> 3     "source": {
#       4         "source_path": PosixPath(
#       5             "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/all_cellprofiler.sqlite"
#       6         ),
#       7         "table_name": "Per_Image",
#       8         "offsets": [0],
#       9     },
#      10     "chunk_size": 1000,
#      11     "offset": 0,
#      12     "dest_path": PosixPath(
#      13         "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet"
#      14     ),
#      15     "data_type_cast_map": None,
#      16 }
#
# Cell In[7], line 4, in <traced_lambda>()
#       1 {
#       2     "source_group_name": "Per_image.sqlite",
#       3     "source": {
# ----> 4         "source_path": PosixPath(
#       5             "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/all_cellprofiler.sqlite"
#       6         ),
#       7         "table_name": "Per_Image",
#       8         "offsets": [0],
#       9     },
#      10     "chunk_size": 1000,
#      11     "offset": 0,
#      12     "dest_path": PosixPath(
#      13         "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet"
#      14     ),
#      15     "data_type_cast_map": None,
#      16 }
#
# NameError: name 'PosixPath' is not defined

# %%
df.sort_values(by="refcount", ascending=False).drop_duplicates(subset="id")[
    "type"
].value_counts()

# %%
df[df["id"] == 5304345792].sort_values(by="refcount", ascending=False).iloc[0]["repr"]

# %%
{
    "source_group_name": "Per_nuclei.sqlite",
    "source": {
        "source_path": PosixPath(
            "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/all_cellprofiler.sqlite"
        ),
        "table_name": "Per_Nuclei",
        "offsets": [0],
    },
    "chunk_size": 1000,
    "offset": 0,
    "dest_path": PosixPath(
        "/Users/dabu5788/Documents/work/CytoTable-benchmarks-d33bs/notebooks/examples/data/test-result.parquet"
    ),
    "data_type_cast_map": None,
}
